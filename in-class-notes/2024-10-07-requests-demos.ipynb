# %% [markdown]
# ## HTTP and Python demos
#
# demo notebook

# %%
import requests

# %% [markdown]
# ## Defining a URL / URI

# %%
url = 'https://www.loc.gov'
lccn_url = 'https://lccn.loc.gov'

# %%
r = requests.get(url)

# %%
r.url
# Out:
# 'https://www.loc.gov/'

# %%
r.status_code
# Out:
# 200

# %%
r.headers
# Out:
# {'Date': 'Mon, 07 Oct 2024 15:06:49 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Content-Length': '175996', 'Connection': 'keep-alive', 'access-control-allow-origin': '*', 'referrer-policy': 'no-referrer-when-downgrade', 'strict-transport-security': 'max-age=3600; preload', 'x-content-type-options': 'nosniff', 'x-frame-options': 'sameorigin', 'etag': '"2ed93bba2690410821c95e37a63cc1a0"', 'expires': 'Mon, 07 Oct 2024 15:48:12 GMT', 'content-security-policy': "block-all-mixed-content;         default-src https://loc.gov/ https://*.loc.gov/ ;         media-src https://loc.gov/ https://*.loc.gov/              https://*.readspeaker.com/             https://*.arcgis.com/ https://*.arcgisonline.com/  https://webapps-cdn.esri.com/             blob:;         worker-src https://loc.gov/ https://*.loc.gov/              blob:;         font-src https://loc.gov/ https://*.loc.gov/              https://*.arcgis.com/ https://*.arcgisonline.com/  https://webapps-cdn.esri.com/             https://ssl.p.jwpcdn.com/             data:;         img-src https://loc.gov/ https://*.loc.gov/              https://congress.gov/ https://*.congress.gov/             https://*.readspeaker.com/             https://*.arcgis.com/ https://*.arcgisonline.com/  https://webapps-cdn.esri.com/             https://*.ssa.gov/             https://dpm.demdex.net/             https://cm.everesttech.net/             https://*.amazonaws.com             data:             blob:;         connect-src https://loc.gov/ https://*.loc.gov/              https://*.arcgis.com/ https://*.arcgisonline.com/  https://webapps-cdn.esri.com/             https://chat-us.libanswers.com/             https://thelibraryofcongress.tt.omtrdc.net/             https://dpm.demdex.net/ \t        https://d3c605m4lmznjl.cloudfront.net/             https://*.s3.us-east-1.amazonaws.com/;         style-src https://loc.gov/ https://*.loc.gov/              https://*.readspeaker.com/             https://*.arcgis.com/ https://*.arcgisonline.com/  https://webapps-cdn.esri.com/             https://ssl.p.jwpcdn.com/             https://assets.adobedtm.com/             https://*.ssa.gov/             'unsafe-inline'             blob:;         script-src https://loc.gov/ https://*.loc.gov/              https://*.readspeaker.com/             https://*.arcgis.com/ https://*.arcgisonline.com/  https://webapps-cdn.esri.com/             https://ssl.p.jwpcdn.com/             https://assets.adobedtm.com/             https://*.blackbaudcdn.net/ https://*.blackbaud.com/             https://ajax.googleapis.com/ajax/libs/jquery/             https://*.ssa.gov/             https://s.ytimg.com/             'unsafe-inline'             'unsafe-eval';         frame-src https://loc.gov/ https://*.loc.gov/              https://*.readspeaker.com/             https://*.blackbaudcdn.net/ https://*.blackbaud.com/             https://www.nlstalkingbooks.org/             https://unitedstateslibraryofcongress.demdex.net             https://www.youtube-nocookie.com/;         frame-ancestors https://loc.gov/ https://*.loc.gov/              https://*.blackbaudcdn.net/ https://*.blackbaud.com/             https://loc.libwizard.com/;         report-uri https://errorlogging.loc.gov/api/51/security/?sentry_key=2176ae0b9acd4cd59297edc0e064cc95&sentry_environment=production ;", 'x-grace': 'none', 'x-nearside-cache': 'MISS', 'x-nearside-cache-hits': '0', 'Cache-Control': 'no-transform, max-age=3600', 'CF-Cache-Status': 'HIT', 'Age': '513', 'Accept-Ranges': 'bytes', 'Vary': 'Accept-Encoding', 'Server': 'cloudflare', 'CF-RAY': '8ceecc1b4d49a952-DTW'}

# %%
for header in r.headers:
    print(header, ':', r.headers[header])
# Out:
# Date : Mon, 07 Oct 2024 15:06:49 GMT
# Content-Type : text/html; charset=UTF-8
# Content-Length : 175996
# Connection : keep-alive
# access-control-allow-origin : *
# referrer-policy : no-referrer-when-downgrade
# strict-transport-security : max-age=3600; preload
# x-content-type-options : nosniff
# x-frame-options : sameorigin
# etag : "2ed93bba2690410821c95e37a63cc1a0"
# expires : Mon, 07 Oct 2024 15:48:12 GMT
# content-security-policy : block-all-mixed-content;         default-src https://loc.gov/ https://*.loc.gov/ ;         media-src https://loc.gov/ https://*.loc.gov/              https://*.readspeaker.com/             https://*.arcgis.com/ https://*.arcgisonline.com/  https://webapps-cdn.esri.com/             blob:;         worker-src https://loc.gov/ https://*.loc.gov/              blob:;         font-src https://loc.gov/ https://*.loc.gov/              https://*.arcgis.com/ https://*.arcgisonline.com/  https://webapps-cdn.esri.com/             https://ssl.p.jwpcdn.com/             data:;         img-src https://loc.gov/ https://*.loc.gov/              https://congress.gov/ https://*.congress.gov/             https://*.readspeaker.com/             https://*.arcgis.com/ https://*.arcgisonline.com/  https://webapps-cdn.esri.com/             https://*.ssa.gov/             https://dpm.demdex.net/             https://cm.everesttech.net/             https://*.amazonaws.com             data:             blob:;         connect-src https://loc.gov/ https://*.loc.gov/              https://*.arcgis.com/ https://*.arcgisonline.com/  https://webapps-cdn.esri.com/             https://chat-us.libanswers.com/             https://thelibraryofcongress.tt.omtrdc.net/             https://dpm.demdex.net/ 	        https://d3c605m4lmznjl.cloudfront.net/             https://*.s3.us-east-1.amazonaws.com/;         style-src https://loc.gov/ https://*.loc.gov/              https://*.readspeaker.com/             https://*.arcgis.com/ https://*.arcgisonline.com/  https://webapps-cdn.esri.com/             https://ssl.p.jwpcdn.com/             https://assets.adobedtm.com/             https://*.ssa.gov/             'unsafe-inline'             blob:;         script-src https://loc.gov/ https://*.loc.gov/              https://*.readspeaker.com/             https://*.arcgis.com/ https://*.arcgisonline.com/  https://webapps-cdn.esri.com/             https://ssl.p.jwpcdn.com/             https://assets.adobedtm.com/             https://*.blackbaudcdn.net/ https://*.blackbaud.com/             https://ajax.googleapis.com/ajax/libs/jquery/             https://*.ssa.gov/             https://s.ytimg.com/             'unsafe-inline'             'unsafe-eval';         frame-src https://loc.gov/ https://*.loc.gov/              https://*.readspeaker.com/             https://*.blackbaudcdn.net/ https://*.blackbaud.com/             https://www.nlstalkingbooks.org/             https://unitedstateslibraryofcongress.demdex.net             https://www.youtube-nocookie.com/;         frame-ancestors https://loc.gov/ https://*.loc.gov/              https://*.blackbaudcdn.net/ https://*.blackbaud.com/             https://loc.libwizard.com/;         report-uri https://errorlogging.loc.gov/api/51/security/?sentry_key=2176ae0b9acd4cd59297edc0e064cc95&sentry_environment=production ;
# x-grace : none
# x-nearside-cache : MISS
# x-nearside-cache-hits : 0
# Cache-Control : no-transform, max-age=3600
# CF-Cache-Status : HIT
# Age : 513
# Accept-Ranges : bytes
# Vary : Accept-Encoding
# Server : cloudflare
# CF-RAY : 8ceecc1b4d49a952-DTW

# %% [markdown]
# ## Looking at the response

# %%
r.text
# Out:
# '<!DOCTYPE html>\n\n\n<html lang="en" class="no-js" prefix="lc: http://loc.gov/#">\n<head>\n\n<meta name="description"\n      content="The Library of Congress is the nation\'s oldest federal cultural institution, and it serves as the research arm of Congress. It is also the largest library in the world, with more than 162 million items. The collections include books, sound recordings, motion pictures, photographs, maps, and manuscripts." />\n\n<meta name="dc.identifier"\n      content="http://www.loc.gov/" />\n\n<meta rel="canonical"\n      href="http://loc.gov/" />\n\n    \n<meta charset="utf-8">\n<meta name="viewport" content="width=device-width,initial-scale=1"/>\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="version" content="$Revision$"/>\n<meta name="msvalidate.01" content="5C89FB9D99590AB2F55BD95C3A59BD81"/>\n<link title="schema(DC)" rel="schema.dc" href="http://purl.org/dc/elements/1.1/"/>\n<meta name="dc.language" content="eng" />\n<meta name="dc.source" content="Library of Congress, Washington, D.C. 20540 USA" />\n\n\n\n<meta property="fb:admins" content="libraryofcongress"/>\n<meta property="og:site_name" content="The Library of Congress"/>\n<meta property="og:type" content="article" />\n\n\n<meta property="twitter:site" content="librarycongress"/>\n\n\n\n \n\n\n    <title>\n       Home | Library of Congress\n    </title>\n    <meta name="dc.title"\n          content="Home | Library of Congress" />\n    <meta property="og:title"\n          content="Home | Library of Congress" />\n\n    \n        <meta name=\'description\' content=\'The world&#x27;s largest library. View historic photos, maps, books and more. Contact experts for help with research. Plan a visit. Home of U.S. Copyright Office.\'/>\n        <meta property="og:description" content="The world&#x27;s largest library. View historic photos, maps, books and more. Contact experts for help with research. Plan a visit. Home of U.S. Copyright Office." />\n    \n\n    <meta name="dc.rights" content="Text is U.S. Government Work" />\n    <link rel="dc.rights" title="Rights Restriction" href="http://www.loc.gov/text-us-government-work" />\n\n    \n        <meta name=\'dc.type\' content=\'web page\'/>\n    \n\n    \n\n    \n\n    \n\n    \n\n    \n        <meta property="og:image" content=\'http://www.loc.gov/static/images/favicons/open-graph-logo.png\' />\n        <meta property="og:image:secure_url" content=\'https://www.loc.gov/static/images/favicons/open-graph-logo.png\' />\n        <meta property="og:image:width" content="1200"/>\n        <meta property="og:image:height" content="630"/>\n    \n\n    \n\n    \n\n    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n    \n\n\n\n\n<link href=\'/static/stylesheets/base.css\'\n    type=\'text/css\'\n    rel=\'stylesheet\' />\n<link href="/static/fonts/OpenSans-Regular.woff2"\n    rel=\'preload\'\n    as=\'font\'\n    type=\'font/woff2\'\n    crossorigin />\n<link href="/static/fonts/OpenSans-Bold.woff2"\n    rel=\'preload\'\n    as=\'font\'\n    type=\'font/woff2\'\n    crossorigin />\n<link href="/static/css/fa/fonts/fontawesome-webfont.woff2?v=4.6.3"\n    rel=\'preload\'\n    as=\'font\'\n    type=\'font/woff2\'\n    crossorigin />\n\n<link href="/static/fonts/RobotoSlab-Bold.woff2"\n    rel=\'preload\'\n    as=\'font\'\n    type=\'font/woff2\'\n    crossorigin />\n\n\n\n\n\n\n\n\n\n\n\n\n<script src="https://assets.adobedtm.com/dac62e20b491e735c6b56e64c39134d8ee93f9cf/satelliteLib-6b47f831c184878d7338d4683ecf773a17973bb9.js"></script>\n\n\n\n<script type="text/javascript"\n    src=\'/static/js/lib/jquery-1.8.2.js\'></script>\n\n\n\n\n\n\n\n    \n\n<script type="text/javascript">\n/**\n * Timing.js 1.0.4\n * Copyright 2015 Addy Osmani\n */\n(function(window) {\n    \'use strict\';\n\n    /**\n     * Navigation Timing API helpers\n     * timing.getTimes();\n     **/\n    window.timing = window.timing || {\n        /**\n         * Outputs extended measurements using Navigation Timing API\n         * @param  Object  ...

# %% [markdown]
# ## Modifying our request with parameters

# %%
parameters = {'fo':'json'}

# %%
r = requests.get(url, params=parameters)

# %%
print(r.url, r.status_code)
# Out:
# https://www.loc.gov/?fo=json 200

# %%
r.text
# Out:
# '{"_featured_events": [{"category": "Concert", "day": 30, "link": "/item/event-398220/", "month": "Jan", "time": "8:00 p.m. - 10:00 p.m.", "title": "Dunedin Consort"}, {"category": "Concert", "day": 31, "link": "/item/event-398223/", "month": "Jan", "time": "8:00 p.m. - 10:00 p.m.", "title": "Asko|Sch\\u00f6nberg Ensemble Concert I"}, {"category": "Lecture", "day": 5, "link": "/item/event-397800/", "month": "Feb", "time": "11:00 a.m. - Noon", "title": "Gallery Talk: Rosa Parks, Before the Bus"}], "_featured_exhibits": [{"dates": "Through September 2020", "link": "/exhibitions/rosa-parks-in-her-own-words/about-this-exhibition/", "thumb": "/static/home/images/your-library/exhibitions/Rosa=Parks-Terek-Portrait-130x84.jpg", "title": "Rosa Parks: In Her Own Words"}, {"dates": "Through September 2020", "link": "/exhibitions/women-fight-for-the-vote/about-this-exhibition/", "thumb": "/static/home/images/your-library/exhibitions/exhibitions-women-suffrage.jpg", "title": "Shall Not Be Denied: Women Fight for the Vote"}, {"dates": "Through September 2020", "link": "/exhibitions/comic-art/about-this-exhibition/", "thumb": "/static/home/images/your-library/exhibitions/comic-art.jpg", "title": "Comic Art: 120 Years of Panels and Pages"}], "_featured_item": {"image_mobile": "/static/home/images/trending/featured/ice-skating2_480x309.jpg", "image_tablet": "/static/home/images/trending/featured/ice-skating2_750x483.jpg", "link": "/item/2016712624/", "portal": "Featured Item", "title": "Ice Skating, ca. 1873-1916"}, "_featured_news": [{"date": "December 18, 2019", "link": "/item/prn-19-121/", "title": "Librarian of Congress Appoints Maria Strong as Acting Register of Copyrights"}, {"date": "December 18, 2019", "link": "/item/prn-19-120/", "title": "New Endowment to Support National Library Service for the Blind and Print Disabled"}, {"date": "December 16, 2019", "link": "/item/prn-19-119/", "title": "Library Opens Nominations for Outstanding Federal Libraries, Librarians and Library Technicians"}, {"date": "December 12, 2019", "link": "/item/prn-19-118/", "title": "Library of Congress Opens Applications for Librarians-in-Residence Program"}], "_featured_video_banner": {"caption": "2024 National Book Festival Main Stage", "description": "Watch programs from the Main Stage live on Aug. 24 from 9:30 a.m. to 7:40 p.m., including: James Patterson, James McBride, Doris Kearns Goodwin, Max Greenfield, Sandra Cisneros, Abby Jimenez and Casey McQuiston, Tamron Hall and Lish Steiling, James S.A. Corey, and Rebecca Yarros.", "link": "https://www.youtube.com/watch?v=IKbscwQ9lQY", "media_url": "https://www.youtube-nocookie.com/embed/IKbscwQ9lQY", "portal": "National Book Festival", "position": "top", "title": "Watch LIVE: National Book Festival Main Stage"}, "breadcrumbs": [{"Home | Library of Congress": "https://www.loc.gov"}], "featured_content": [{"alt": "Children wearing typical dresses for Ecuadorian National Day. Corona Plaza, Queens NY, 2021. Photo by Camilo J. Vergara", "banner": "/static/home/images/featured/heritage/hispheritage2022_1200x560.jpg", "description": "U.S. cultural institutions pay tribute to generations of Hispanic Americans who have enriched our nation.", "link": "https://www.hispanicheritagemonth.gov/", "title": "National Hispanic Heritage Month"}, {"alt": "Image of Eddie Palmieri, a smiling man in a suit and holding a cigar, sitting at a Yamaha piano", "banner": "/static/home/images/featured/programs/2024concerts-oct-eddie-palmier_1200x560.jpg", "description": "Celebrate 100 years of performing arts and music at the Library.", "link": "https://newsroom.loc.gov/news/library-of-congress-announces-fall-2024-concert-series/s/8df5fa69-0471-4633-8bcf-c5dce4293ba6", "title": "Concerts from the Library"}, {"alt": "A view of the Great Hall of the Thomas Jefferson Building of the Library of Congress, with many people shown enjoying the beautiful architecture in the hall, on the stairs and in the gallery above", "banner": "/static/home/image ...

# %%
parameters = {'q':'kittens','fo':'json'}

# %%
search_url = 'https://www.loc.gov/search'

# %%
r = requests.get(search_url, params=parameters)
print(r.url, r.status_code)
# Out:
# https://www.loc.gov/search?q=kittens&fo=json 200

# %% [markdown]
# ## Request an item and its metadata from LOC

# %%
url
# Out:
# 'https://www.loc.gov'

# %%
item_info = '/resource/ds.06560/'

# %%
r = requests.get(url + item_info)
print(r.url)
# Out:
# https://www.loc.gov/resource/ds.06560/

# %%
parameters = {'fo':'json'}

# %%
r = requests.get(url + item_info, params=parameters)
print(r.url, r.status_code)
# Out:
# https://www.loc.gov/resource/ds.06560/?fo=json 200

# %% [markdown]
# ## Look at the JSON response & find metadata

# %%
r.text
# Out:
# '{"articles_and_essays": [{"score": 6.800294, "title": "Postcards: Greetings from the Prints & Photographs Division", "url": "https://guides.loc.gov/postcards"}], "cite_this": {"apa": "Gilbert, C. <cite>Main public library building - Detroit</cite>. Detroit Michigan, None. [Brooklyn, n.y.: the albertype co., between 1921 and 1930?] [Photograph] Retrieved from the Library of Congress, https://www.loc.gov/item/2014647618/.", "chicago": "Gilbert, Cass, Architect. <cite>Main public library building - Detroit</cite>. Detroit Michigan, None. [Brooklyn, n.y.: the albertype co., between 1921 and 1930?] Photograph. https://www.loc.gov/item/2014647618/.", "mla": "Gilbert, Cass, Architect. <cite>Main public library building - Detroit</cite>. [Brooklyn, n.y.: the albertype co., between 1921 and 1930?] Photograph. Retrieved from the Library of Congress, &lt;www.loc.gov/item/2014647618/&gt;."}, "item": {"_version_": 1768319195339030528, "access_restricted": false, "aka": ["https://www.loc.gov/pictures/item/2014647618/", "http://www.loc.gov/item/2014647618/", "http://www.loc.gov/pictures/item/2014647618/", "https://www.loc.gov/pictures/collection/cph/item/2014647618/", "http://www.loc.gov/pictures/collection/cph/item/2014647618/", "https://hdl.loc.gov/loc.pnp/ds.06560", "https://hdl.loc.gov/loc.pnp/ds.06560", "http://www.loc.gov/resource/ds.06560/", "http://lccn.loc.gov/2014647618"], "call_number": "PCRD14, no. 171 [P&P]", "campaigns": [], "contributor_names": ["Gilbert, Cass, 1859-1934, architect"], "contributors": [{"gilbert, cass": "https://www.loc.gov/search/?fa=contributor:gilbert,+cass&fo=json"}], "control_number": "", "created": "2023-06-06T06:30:58Z", "created_published": ["[Brooklyn, N.Y.] : [The Albertype Co.], [between 1921 and 1930?]"], "created_published_date": "[between 1921 and 1930?]", "date": "1921", "dates": [{"1921": "https://www.loc.gov/search/?dates=1921/1921&fo=json"}], "description": ["1 photograph : hand-colored collotype ; sheet 14 x 21 cm. | Photograph shows view of Carnegie library in Detroit, Michigan."], "digital_id": ["ds 06560 https://hdl.loc.gov/loc.pnp/ds.06560"], "digitized": true, "display_offsite": true, "extract_timestamp": "2023-06-10T12:35:59.658Z", "extract_urls": ["http://www.loc.gov/pictures/collection/cph/item/2014647618/#cph", "http://lccn.loc.gov/2014647618#catalog-split-07"], "format": [{"photo, print, drawing": "https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json"}], "format_headings": ["Advertisements--1920-1930.", "Architectural photographs--1920-1930.", "Collotypes--Hand-colored--1920-1930.", "Postcards--1920-1930."], "genre": ["Advertisements--1920-1930", "Postcards--1920-1930", "Architectural photographs--1920-1930", "Collotypes--Hand-colored--1920-1930"], "group": ["cph", "catalog-split-07", "catalog", "miscellaneous-items-high-demand", "main-catalog-split-07", "main-catalog"], "hassegments": false, "id": "http://www.loc.gov/item/2014647618/", "image_url": ["https://tile.loc.gov/storage-services/service/pnp/ds/06500/06560_150px.jpg#h=107&w=150", "https://tile.loc.gov/storage-services/service/pnp/ds/06500/06560r.jpg#h=454&w=640", "https://tile.loc.gov/storage-services/service/pnp/ds/06500/06560v.jpg#h=727&w=1024"], "index": 1, "item": {"call_number": "PCRD14, no. 171 [P&P]", "contributor_names": ["Gilbert, Cass, 1859-1934, architect "], "contributors": ["Gilbert, Cass, 1859-1934, architect"], "control_number": "2014647618", "created": "2023-06-06T06:30:58Z", "created_published": "[Brooklyn, N.Y.] : [The Albertype Co.], [between 1921 and 1930?]", "created_published_date": "[between 1921 and 1930?]", "creators": [{"link": "https://www.loc.gov/pictures/related/?fi=name&q=Gilbert%2C%20Cass%2C%201859-1934&co=cph", "role": "architect", "title": "Gilbert, Cass, 1859-1934"}], "date": "[between 1921 and 1930?]", "digital_id": ["ds 06560 https://hdl.loc.gov/loc.pnp/ds.06560"], "display_offsite": true, "format": ["still image"], "formats": [{"link": "https://www.loc.gov/pictur ...

# %%
item_metadata = r.json()

# %%
print(item_metadata)
# Out:
# {'articles_and_essays': [{'score': 6.800294, 'title': 'Postcards: Greetings from the Prints & Photographs Division', 'url': 'https://guides.loc.gov/postcards'}], 'cite_this': {'apa': 'Gilbert, C. <cite>Main public library building - Detroit</cite>. Detroit Michigan, None. [Brooklyn, n.y.: the albertype co., between 1921 and 1930?] [Photograph] Retrieved from the Library of Congress, https://www.loc.gov/item/2014647618/.', 'chicago': 'Gilbert, Cass, Architect. <cite>Main public library building - Detroit</cite>. Detroit Michigan, None. [Brooklyn, n.y.: the albertype co., between 1921 and 1930?] Photograph. https://www.loc.gov/item/2014647618/.', 'mla': 'Gilbert, Cass, Architect. <cite>Main public library building - Detroit</cite>. [Brooklyn, n.y.: the albertype co., between 1921 and 1930?] Photograph. Retrieved from the Library of Congress, &lt;www.loc.gov/item/2014647618/&gt;.'}, 'item': {'_version_': 1768319195339030528, 'access_restricted': False, 'aka': ['https://www.loc.gov/pictures/item/2014647618/', 'http://www.loc.gov/item/2014647618/', 'http://www.loc.gov/pictures/item/2014647618/', 'https://www.loc.gov/pictures/collection/cph/item/2014647618/', 'http://www.loc.gov/pictures/collection/cph/item/2014647618/', 'https://hdl.loc.gov/loc.pnp/ds.06560', 'https://hdl.loc.gov/loc.pnp/ds.06560', 'http://www.loc.gov/resource/ds.06560/', 'http://lccn.loc.gov/2014647618'], 'call_number': 'PCRD14, no. 171 [P&P]', 'campaigns': [], 'contributor_names': ['Gilbert, Cass, 1859-1934, architect'], 'contributors': [{'gilbert, cass': 'https://www.loc.gov/search/?fa=contributor:gilbert,+cass&fo=json'}], 'control_number': '', 'created': '2023-06-06T06:30:58Z', 'created_published': ['[Brooklyn, N.Y.] : [The Albertype Co.], [between 1921 and 1930?]'], 'created_published_date': '[between 1921 and 1930?]', 'date': '1921', 'dates': [{'1921': 'https://www.loc.gov/search/?dates=1921/1921&fo=json'}], 'description': ['1 photograph : hand-colored collotype ; sheet 14 x 21 cm. | Photograph shows view of Carnegie library in Detroit, Michigan.'], 'digital_id': ['ds 06560 https://hdl.loc.gov/loc.pnp/ds.06560'], 'digitized': True, 'display_offsite': True, 'extract_timestamp': '2023-06-10T12:35:59.658Z', 'extract_urls': ['http://www.loc.gov/pictures/collection/cph/item/2014647618/#cph', 'http://lccn.loc.gov/2014647618#catalog-split-07'], 'format': [{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}], 'format_headings': ['Advertisements--1920-1930.', 'Architectural photographs--1920-1930.', 'Collotypes--Hand-colored--1920-1930.', 'Postcards--1920-1930.'], 'genre': ['Advertisements--1920-1930', 'Postcards--1920-1930', 'Architectural photographs--1920-1930', 'Collotypes--Hand-colored--1920-1930'], 'group': ['cph', 'catalog-split-07', 'catalog', 'miscellaneous-items-high-demand', 'main-catalog-split-07', 'main-catalog'], 'hassegments': False, 'id': 'http://www.loc.gov/item/2014647618/', 'image_url': ['https://tile.loc.gov/storage-services/service/pnp/ds/06500/06560_150px.jpg#h=107&w=150', 'https://tile.loc.gov/storage-services/service/pnp/ds/06500/06560r.jpg#h=454&w=640', 'https://tile.loc.gov/storage-services/service/pnp/ds/06500/06560v.jpg#h=727&w=1024'], 'index': 1, 'item': {'call_number': 'PCRD14, no. 171 [P&P]', 'contributor_names': ['Gilbert, Cass, 1859-1934, architect '], 'contributors': ['Gilbert, Cass, 1859-1934, architect'], 'control_number': '2014647618', 'created': '2023-06-06T06:30:58Z', 'created_published': '[Brooklyn, N.Y.] : [The Albertype Co.], [between 1921 and 1930?]', 'created_published_date': '[between 1921 and 1930?]', 'creators': [{'link': 'https://www.loc.gov/pictures/related/?fi=name&q=Gilbert%2C%20Cass%2C%201859-1934&co=cph', 'role': 'architect', 'title': 'Gilbert, Cass, 1859-1934'}], 'date': '[between 1921 and 1930?]', 'digital_id': ['ds 06560 https://hdl.loc.gov/loc.pnp/ds.06560'], 'display_offsite': True, 'format': ['still image'], 'formats': [{'link': 'https://www.loc.gov/picture ...

# %%
for data in item_metadata:
    print(data)
# Out:
# articles_and_essays
# cite_this
# item
# more_like_this
# options
# page
# pagination
# related
# related_items
# reproductions
# resource
# resources
# thesaurus_entry
# timestamp
# type
# unrestricted
# views

# %%
item_metadata['item']
# Out:
# {'_version_': 1768319195339030528,
#  'access_restricted': False,
#  'aka': ['https://www.loc.gov/pictures/item/2014647618/',
#   'http://www.loc.gov/item/2014647618/',
#   'http://www.loc.gov/pictures/item/2014647618/',
#   'https://www.loc.gov/pictures/collection/cph/item/2014647618/',
#   'http://www.loc.gov/pictures/collection/cph/item/2014647618/',
#   'https://hdl.loc.gov/loc.pnp/ds.06560',
#   'https://hdl.loc.gov/loc.pnp/ds.06560',
#   'http://www.loc.gov/resource/ds.06560/',
#   'http://lccn.loc.gov/2014647618'],
#  'call_number': 'PCRD14, no. 171 [P&P]',
#  'campaigns': [],
#  'contributor_names': ['Gilbert, Cass, 1859-1934, architect'],
#  'contributors': [{'gilbert, cass': 'https://www.loc.gov/search/?fa=contributor:gilbert,+cass&fo=json'}],
#  'control_number': '',
#  'created': '2023-06-06T06:30:58Z',
#  'created_published': ['[Brooklyn, N.Y.] : [The Albertype Co.], [between 1921 and 1930?]'],
#  'created_published_date': '[between 1921 and 1930?]',
#  'date': '1921',
#  'dates': [{'1921': 'https://www.loc.gov/search/?dates=1921/1921&fo=json'}],
#  'description': ['1 photograph : hand-colored collotype ; sheet 14 x 21 cm. | Photograph shows view of Carnegie library in Detroit, Michigan.'],
#  'digital_id': ['ds 06560 https://hdl.loc.gov/loc.pnp/ds.06560'],
#  'digitized': True,
#  'display_offsite': True,
#  'extract_timestamp': '2023-06-10T12:35:59.658Z',
#  'extract_urls': ['http://www.loc.gov/pictures/collection/cph/item/2014647618/#cph',
#   'http://lccn.loc.gov/2014647618#catalog-split-07'],
#  'format': [{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}],
#  'format_headings': ['Advertisements--1920-1930.',
#   'Architectural photographs--1920-1930.',
#   'Collotypes--Hand-colored--1920-1930.',
#   'Postcards--1920-1930.'],
#  'genre': ['Advertisements--1920-1930',
#   'Postcards--1920-1930',
#   'Architectural photographs--1920-1930',
#   'Collotypes--Hand-colored--1920-1930'],
#  'group': ['cph',
#   'catalog-split-07',
#   'catalog',
#   'miscellaneous-items-high-demand',
#   'main-catalog-split-07',
#   'main-catalog'],
#  'hassegments': False,
#  'id': 'http://www.loc.gov/item/2014647618/',
#  'image_url': ['https://tile.loc.gov/storage-services/service/pnp/ds/06500/06560_150px.jpg#h=107&w=150',
#   'https://tile.loc.gov/storage-services/service/pnp/ds/06500/06560r.jpg#h=454&w=640',
#   'https://tile.loc.gov/storage-services/service/pnp/ds/06500/06560v.jpg#h=727&w=1024'],
#  'index': 1,
#  'item': {'call_number': 'PCRD14, no. 171 [P&P]',
#   'contributor_names': ['Gilbert, Cass, 1859-1934, architect '],
#   'contributors': ['Gilbert, Cass, 1859-1934, architect'],
#   'control_number': '2014647618',
#   'created': '2023-06-06T06:30:58Z',
#   'created_published': '[Brooklyn, N.Y.] : [The Albertype Co.], [between 1921 and 1930?]',
#   'created_published_date': '[between 1921 and 1930?]',
#   'creators': [{'link': 'https://www.loc.gov/pictures/related/?fi=name&q=Gilbert%2C%20Cass%2C%201859-1934&co=cph',
#     'role': 'architect',
#     'title': 'Gilbert, Cass, 1859-1934'}],
#   'date': '[between 1921 and 1930?]',
#   'digital_id': ['ds 06560 https://hdl.loc.gov/loc.pnp/ds.06560'],
#   'display_offsite': True,
#   'format': ['still image'],
#   'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Advertisements--1920-1930.&co=cph',
#     'title': 'Advertisements--1920-1930.'},
#    {'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Architectural%20photographs--1920-1930.&co=cph',
#     'title': 'Architectural photographs--1920-1930.'},
#    {'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Collotypes--Hand-colored--1920-1930.&co=cph',
#     'title': 'Collotypes--Hand-colored--1920-1930.'},
#    {'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Postcards--1920-1930.&co=cph',
#     'title': 'Postcards--1920-1930.'}],
#   'genre': ['Advertisements--1920-1930',
#    'Postcards--1920-1930',
#    'Architectural photographs--1920-1930',
#    'Collotypes--Hand-colored--1920-1930'],
#   'id': '2014647618',
#   'language': ['eng'],
#   'link': 'https://www.loc.gov/pictures/item/2014647618/',
#   'location': ['Michigan--Detroit'],
#   'marc': 'https://www.loc.gov/pictures/item/2014647618/marc/',
#   'medium': ['1 photograph : hand-colored collotype ; sheet 14 x 21 cm.'],
#   'medium_brief': '1 photograph :',
#   'mediums': ['1 photograph : hand-colored collotype ; sheet 14 x 21 cm.'],
#   'modified': '2023-06-06T06:31:02Z',
#   'notes': ['Title from item.',
#    'Includes advertisement for Berry Brothers, varnishes and paint specialties.',
#    'Library designed by Cass Gilbert.',
#    '(PR 06 CN 037).'],
#   'other_control_numbers': ['18367073'],
#   'place': [{'latitude': '',
#     'link': 'https://www.loc.gov/pictures/related/?fi=place&q=Michigan--Detroit&co=cph',
#     'longitude': '',
#     'title': 'Michigan--Detroit'}],
#   'raw_collections': ['cph', 'diof', 'pp'],
#   'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print',
#   'reproduction_number': 'LC-DIG-ds-06560 (digital file from original item)',
#   'resource_links': ['https://hdl.loc.gov/loc.pnp/ds.06560'],
#   'rights_advisory': 'No known restrictions on publication.',
#   'rights_information': 'No known restrictions on publication.',
#   'service_low': 'https://tile.loc.gov/storage-services/service/pnp/ds/06500/06560_150px.jpg',
#   'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/ds/06500/06560r.jpg',
#   'sort_date': '1921',
#   'source_created': '2014-11-10T00:00:00Z',
#   'source_modified': '2023-05-31T07:54:19Z',
#   'subject_headings': ['Detroit Public Library--Buildings--1920-1930.',
#    'Berry Brothers--Public relations--1920-1930.',
#    'Carnegie libraries--Michigan--Detroit--1920-1930.',
#    'Public libraries--Michigan--Detroit--1920-1930.',
#    'Michigan--Detroit'],
#   'subjects': ['Detroit Public Library--Buildings--1920-1930',
#    'Berry Brothers--Public relations--1920-1930',
#    'Carnegie libraries--Michigan--Detroit--1920-1930',
#    'Public libraries--Michigan--Detroit--1920-1930'],
#   'summary': 'Photograph shows view of Carnegie library in Detroit, Michigan.',
#   'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/ds/06500/06560_150px.jpg',
#   'title': 'Main public library building - Detroit'},
#  'language': ['english'],
#  'languages': [{'english': 'https://www.loc.gov/search/?fa=language:english&fo=json'}],
#  'library_of_congress_control_number': '2014647618',
#  'link': 'https://www.loc.gov/pictures/item/2014647618/',
#  'location': ['detroit', 'michigan'],
#  'locations': [{'detroit': 'https://www.loc.gov/search/?fa=location:detroit&fo=json'},
#   {'michigan': 'https://www.loc.gov/search/?fa=location:michigan&fo=json'}],
#  'marc': 'https://www.loc.gov/pictures/item/2014647618/marc/',
#  'medium': ['1 photograph : hand-colored collotype ; sheet 14 x 21 cm.'],
#  'medium_brief': '1 photograph :',
#  'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#  'modified': '2023-06-06T06:31:02Z',
#  'notes': ['Title from item.',
#   'Includes advertisement for Berry Brothers, varnishes and paint specialties.',
#   'Library designed by Cass Gilbert.',
#   '(PR 06 CN 037).'],
#  'number': ['http://www.loc.gov/item/18367073',
#   '2023-05-31t07:54:19',
#   'sheet',
#   '2014647618'],
#  'number_carrier_type': ['sheet'],
#  'number_former_id': ['http://www.loc.gov/item/18367073'],
#  'number_lccn': ['2014647618'],
#  'number_source_modified': ['2023-05-31t07:54:19'],
#  'online_format': ['image'],
#  'original_format': ['photo, print, drawing'],
#  'other_control_numbers': ['18367073'],
#  'other_formats': [{'label': 'MARCXML Record',
#    'link': 'https://lccn.loc.gov/2014647618/marcxml'},
#   {'label': 'MODS Record', 'link': 'https://lccn.loc.gov/2014647618/mods'},
#   {'label': 'Dublin Core Record',
#    'link': 'https://lccn.loc.gov/2014647618/dc'}],
#  'other_title': [],
#  'partof': [{'count': 118304,
#    'title': 'miscellaneous items in high demand',
#    'url': 'https://www.loc.gov/search/?fa=partof:miscellaneous+items+in+high+demand&fo=json'},
#   {'count': 952870,
#    'title': 'prints & photographs online catalog (library of congress)',
#    'url': 'https://www.loc.gov/search/?fa=partof:prints+%26+photographs+online+catalog+%28library+of+congress%29&fo=json'},
#   {'count': 1078496,
#    'title': 'prints and photographs division',
#    'url': 'https://www.loc.gov/search/?fa=partof:prints+and+photographs+division&fo=json'},
#   {'count': 1584529,
#    'title': 'catalog',
#    'url': 'https://www.loc.gov/search/?fa=partof:catalog&fo=json'}],
#  'place': [{'latitude': '',
#    'link': 'https://www.loc.gov/pictures/related/?fi=place&q=Michigan--Detroit&co=cph',
#    'longitude': '',
#    'title': 'Michigan--Detroit'}],
#  'raw_collections': ['cph', 'diof', 'pp'],
#  'related': {'neighbors': 'https://www.loc.gov/pictures/related/?&co=cph&pk=2014647618&st=gallery&sb=call_number#focus'},
#  'repository': ['Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print'],
#  'reproduction_number': 'LC-DIG-ds-06560 (digital file from original item)',
#  'reproductions': [],
#  'resource_links': ['https://hdl.loc.gov/loc.pnp/ds.06560'],
#  'resources': [{'caption': 'digital file from original item',
#    'files': 1,
#    'image': 'https://tile.loc.gov/storage-services/service/pnp/ds/06500/06560_150px.jpg',
#    'url': 'https://www.loc.gov/resource/ds.06560/'}],
#  'rights': [],
#  'rights_advisory': 'No known restrictions on publication.',
#  'rights_information': 'No known restrictions on publication.',
#  'score': 19.235737,
#  'shard': '00',
#  'shelf_id': 'PCRD14, no. 171 [P&P]',
#  'site': ['pictures', 'catalog'],
#  'sort_date': '1921',
#  'source_created': '2014-11-10T00:00:00Z',
#  'source_modified': '2000-01-01T12:00:00Z',
#  'subject': ['advertisements',
#   'postcards',
#   'buildings',
#   'michigan',
#   'berry brothers',
#   'public relations',
#   'architectural photographs',
#   'collotypes',
#   'hand-colored',
#   'detroit public library',
#   'detroit',
#   'public libraries',
#   'carnegie libraries'],
#  'subject_headings': ['Detroit Public Library--Buildings--1920-1930',
#   'Berry Brothers--Public relations--1920-1930',
#   'Carnegie libraries--Michigan--Detroit--1920-1930',
#   'Public libraries--Michigan--Detroit--1920-1930'],
#  'subjects': [{'advertisements': 'https://www.loc.gov/search/?fa=subject:advertisements&fo=json'},
#   {'architectural photographs': 'https://www.loc.gov/search/?fa=subject:architectural+photographs&fo=json'},
#   {'berry brothers': 'https://www.loc.gov/search/?fa=subject:berry+brothers&fo=json'},
#   {'buildings': 'https://www.loc.gov/search/?fa=subject:buildings&fo=json'},
#   {'carnegie libraries': 'https://www.loc.gov/search/?fa=subject:carnegie+libraries&fo=json'},
#   {'collotypes': 'https://www.loc.gov/search/?fa=subject:collotypes&fo=json'},
#   {'detroit': 'https://www.loc.gov/search/?fa=subject:detroit&fo=json'},
#   {'detroit public library': 'https://www.loc.gov/search/?fa=subject:detroit+public+library&fo=json'},
#   {'hand-colored': 'https://www.loc.gov/search/?fa=subject:hand-colored&fo=json'},
#   {'michigan': 'https://www.loc.gov/search/?fa=subject:michigan&fo=json'},
#   {'postcards': 'https://www.loc.gov/search/?fa=subject:postcards&fo=json'},
#   {'public libraries': 'https://www.loc.gov/search/?fa=subject:public+libraries&fo=json'},
#   {'public relations': 'https://www.loc.gov/search/?fa=subject:public+relations&fo=json'}],
#  'summary': 'Photograph shows view of Carnegie library in Detroit, Michigan.',
#  'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/ds/06500/06560_150px.jpg',
#  'timestamp': '2023-06-10T12:36:39.712Z',
#  'title': 'Main public library building - Detroit',
#  'type': ['photo, print, drawing'],
#  'unrestricted': True,
#  'url': 'https://www.loc.gov/item/2014647618/'}

# %%
item_metadata['item']['library_of_congress_control_number']
# Out:
# '2014647618'

# %%
item_lccn = item_metadata['item']['library_of_congress_control_number']
print(item_lccn)
# Out:
# 2014647618

# %% [markdown]
# # Reuse that metadata to construct the LCCN URL... the permalink!

# %%
r = requests.get(lccn_url + '/' + item_lccn)
print(r.url, r.status_code)
# Out:
# https://catalog.loc.gov/vwebv/search?searchCode=LCCN&searchArg=2014647618&searchType=1&permalink=y 200

# %%
r = requests.get(lccn_url + '/' + item_lccn + '/dc')
print(r.url, r.status_code)
print(r.text)
# Out:
# https://lccn.loc.gov/2014647618/dc 200
# <?xml version="1.0" encoding="UTF-8"?><srw_dc:dc xmlns:srw_dc="info:srw/schema/1/dc-schema" xmlns:zs="http://docs.oasis-open.org/ns/search-ws/sruResponse" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="info:srw/schema/1/dc-schema http://www.loc.gov/standards/sru/resources/dc-schema.xsd">
#   <title xmlns="http://purl.org/dc/elements/1.1/">Main public library building - Detroit [graphic].</title>
#   <creator xmlns="http://purl.org/dc/elements/1.1/">Gilbert, Cass, 1859-1934, architect.</creator>
#   <type xmlns="http://purl.org/dc/elements/1.1/">still image</type>
#   <type xmlns="http://purl.org/dc/elements/1.1/">Advertisements 1920-1930. gmgpc</type>
#   <type xmlns="http://purl.org/dc/elements/1.1/">Postcards 1920-1930. gmgpc</type>
#   <type xmlns="http://purl.org/dc/elements/1.1/">Architectural photographs 1920-1930. gmgpc</type>
#   <type xmlns="http://purl.org/dc/elements/1.1/">Collotypes Hand-colored 1920-1930. gmgpc</type>
#   <publisher xmlns="http://purl.org/dc/elements/1.1/">[Brooklyn, N.Y.] :</publisher>
#   <date xmlns="http://purl.org/dc/elements/1.1/">[between 1921 and 1930?]</date>
#   <language xmlns="http://purl.org/dc/elements/1.1/">eng</language>
#   <description xmlns="http://purl.org/dc/elements/1.1/">Photograph shows view of Carnegie library in Detroit, Michigan.</description>
#   <description xmlns="http://purl.org/dc/elements/1.1/">Title from item.</description>
#   <description xmlns="http://purl.org/dc/elements/1.1/">Includes advertisement for Berry Brothers, varnishes and paint specialties.</description>
#   <description xmlns="http://purl.org/dc/elements/1.1/">Library designed by Cass Gilbert.</description>
#   <description xmlns="http://purl.org/dc/elements/1.1/"/>
#   <subject xmlns="http://purl.org/dc/elements/1.1/">Detroit Public Library--Buildings--1920-1930.</subject>
#   <subject xmlns="http://purl.org/dc/elements/1.1/">Berry Brothers--Public relations--1920-1930.</subject>
#   <subject xmlns="http://purl.org/dc/elements/1.1/">Carnegie libraries--Michigan--Detroit--1920-1930.</subject>
#   <subject xmlns="http://purl.org/dc/elements/1.1/">Public libraries--Michigan--Detroit--1920-1930.</subject>
#   <identifier xmlns="http://purl.org/dc/elements/1.1/">http://hdl.loc.gov/loc.pnp/ds.06560</identifier>
#   <rights xmlns="http://purl.org/dc/elements/1.1/">No known restrictions on publication.</rights>
# </srw_dc:dc>
