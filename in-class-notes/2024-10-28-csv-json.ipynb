# %% [markdown]
# # Class notes Oct 28
#
# In-class demos for Oct 28, 2024.

# %% [markdown]
# ## CSV
#
# Working with CSV in Python

# %%
import csv

# %%
# !cat ../data/animal-counts/animals.csv
# Out:
# 2012-11-05,deer,5
# 2012-11-05,rabbit,22
# 2012-11-05,raccoon,7
# 2012-11-06,rabbit,19
# 2012-11-06,deer,2
# 2012-11-06,fox,4
# 2012-11-07,rabbit,16
# 2012-11-07,bear,1

# %%
with open('../data/animal-counts/animals.csv', encoding='utf-8') as f:
    data = csv.reader(f, delimiter=',')
    line_count = 0
    for row in data:
        line_count += 1
        print(row)
    print('Total rows:',line_count)
# Out:
# ['2012-11-05', 'deer', '5']
# ['2012-11-05', 'rabbit', '22']
# ['2012-11-05', 'raccoon', '7']
# ['2012-11-06', 'rabbit', '19']
# ['2012-11-06', 'deer', '2']
# ['2012-11-06', 'fox', '4']
# ['2012-11-07', 'rabbit', '16']
# ['2012-11-07', 'bear', '1']
# Total rows: 8

# %%
with open('../data/animal-counts/animals.csv', encoding='utf-8') as f:
    data = csv.reader(f, delimiter=',')
    line_count = 0
    for row in data:
        line_count += 1
        print(row[0])
    print('Total rows:',line_count)
# Out:
# 2012-11-05
# 2012-11-05
# 2012-11-05
# 2012-11-06
# 2012-11-06
# 2012-11-06
# 2012-11-07
# 2012-11-07
# Total rows: 8

# %%
cols = ['date','animal','count']

with open('../data/animal-counts/animals.csv', encoding='utf-8') as f:
    data = csv.DictReader(f, fieldnames=cols, delimiter=',')
    line_count = 0
    for row in data:
        print(row)
        line_count += 1
    print('Total rows:',line_count)
# Out:
# {'date': '2012-11-05', 'animal': 'deer', 'count': '5'}
# {'date': '2012-11-05', 'animal': 'rabbit', 'count': '22'}
# {'date': '2012-11-05', 'animal': 'raccoon', 'count': '7'}
# {'date': '2012-11-06', 'animal': 'rabbit', 'count': '19'}
# {'date': '2012-11-06', 'animal': 'deer', 'count': '2'}
# {'date': '2012-11-06', 'animal': 'fox', 'count': '4'}
# {'date': '2012-11-07', 'animal': 'rabbit', 'count': '16'}
# {'date': '2012-11-07', 'animal': 'bear', 'count': '1'}
# Total rows: 8

# %%
cols = ['date','animal','count']

with open('../data/animal-counts/animals.csv', encoding='utf-8') as f:
    data = csv.DictReader(f, fieldnames=cols, delimiter=',')
    line_count = 0
    for row in data:
        date = row['date']
        count = row['count']
        animal = row['animal']
        print(f'On { date } someone observed { count } { animal }.')
        line_count += 1
    print('Total rows:',line_count)
# Out:
# On 2012-11-05 someone observed 5 deer.
# On 2012-11-05 someone observed 22 rabbit.
# On 2012-11-05 someone observed 7 raccoon.
# On 2012-11-06 someone observed 19 rabbit.
# On 2012-11-06 someone observed 2 deer.
# On 2012-11-06 someone observed 4 fox.
# On 2012-11-07 someone observed 16 rabbit.
# On 2012-11-07 someone observed 1 bear.
# Total rows: 8

# %% [markdown]
# ## JSON
#
# Working with JSON in Python

# %%
import json

# %%
sampleJSONstring = '''{ "Results": 2, 
"isPrinted" : true, 
"format" : null, 
"books": [
    { "title": "Gone with the Wind", "author":"Mitchell" },
    { "title": "Wuthering Heights", "author": "Bronte" } 
]}
'''
print(sampleJSONstring)
# Out:
# { "Results": 2,
# "isPrinted" : true,
# "format" : null,
# "books": [
#     { "title": "Gone with the Wind", "author":"Mitchell" },
#     { "title": "Wuthering Heights", "author": "Bronte" }
# ]}

# %%
jsonDataasPythonString = json.loads(sampleJSONstring)

# %%
print(jsonDataasPythonString)
# Out:
# {'Results': 2, 'isPrinted': True, 'format': None, 'books': [{'title': 'Gone with the Wind', 'author': 'Mitchell'}, {'title': 'Wuthering Heights', 'author': 'Bronte'}]}

# %%
for key in jsonDataasPythonString:
    print(key)
# Out:
# Results
# isPrinted
# format
# books

# %%
json.dumps(jsonDataasPythonString)
# Out:
# '{"Results": 2, "isPrinted": true, "format": null, "books": [{"title": "Gone with the Wind", "author": "Mitchell"}, {"title": "Wuthering Heights", "author": "Bronte"}]}'

# %%
jsonDataasPythonString
# Out:
# {'Results': 2,
#  'isPrinted': True,
#  'format': None,
#  'books': [{'title': 'Gone with the Wind', 'author': 'Mitchell'},
#   {'title': 'Wuthering Heights', 'author': 'Bronte'}]}

# %%
# write the JSON data object to a file

with open('json-output-test.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(jsonDataasPythonString, indent=2))
    print('wrote',f.name)
# Out:
# wrote json-output-test.json

# %% [markdown]
# More information about these functions in the `examples/json-and-apis-starter.ipynb`.

# %% [markdown]
# ## Working with the APIs

# %%
import json
import requests

# %%
baseURL = 'https://www.loc.gov/'
endpoint = 'search/'

# %%
r = requests.get(baseURL + endpoint, params={'q':'kittens','fo':'json'})

r.url
# Out:
# 'https://www.loc.gov/search/?q=kittens&fo=json'

# %%
response_json = requests.get(baseURL + endpoint, params={'q':'kittens','fo':'json'}).json()

print(response_json)
# Out:
# {'breadcrumbs': [{'Library of Congress': 'https://www.loc.gov'}, {'Search': 'https://www.loc.gov/search/?fo=json&q=kittens'}], 'expert_resources': None, 'facet_trail': [{'facet': 'searchTerms', 'field': 'searchTerms', 'superset': 'https://www.loc.gov/search/?fo=json', 'value': 'kittens'}, {'facet': 'Available Online', 'field': 'digitized', 'superset': 'https://www.loc.gov/search/?all=true&fo=json&q=kittens', 'value': 'digitized'}], 'facet_views': {'calendar': 'https://www.loc.gov/search/?fo=json&fs=calendar&q=kittens', 'chart': 'https://www.loc.gov/search/?fo=json&fs=chart&q=kittens', 'current': 'list', 'list': 'https://www.loc.gov/search/?fo=json&q=kittens'}, 'facets': [{'filters': [{'count': 179667, 'not': None, 'off': None, 'on': 'https://www.loc.gov/search/?fo=json&q=kittens', 'title': 'true'}, {'count': 2979, 'not': None, 'off': None, 'on': 'https://www.loc.gov/search/?all=true&fo=json&q=kittens', 'title': 'false'}], 'title': 'Available Online', 'type': 'digitized'}, {'filters': [{'count': 168087, 'not': 'https://www.loc.gov/search/?fa=original-format!:newspaper&fo=json&q=kittens', 'off': None, 'on': 'https://www.loc.gov/newspapers/?dl=item&fo=json&q=kittens', 'title': 'newspaper'}, {'count': 10091, 'not': 'https://www.loc.gov/search/?fa=original-format!:book&fo=json&q=kittens', 'off': None, 'on': 'https://www.loc.gov/books/?fo=json&q=kittens', 'title': 'book'}, {'count': 690, 'not': 'https://www.loc.gov/search/?fa=original-format!:periodical&fo=json&q=kittens', 'off': None, 'on': 'https://www.loc.gov/search/?fa=original-format:periodical&fo=json&q=kittens', 'title': 'periodical'}, {'count': 457, 'not': 'https://www.loc.gov/search/?fa=original-format!:manuscript/mixed+material&fo=json&q=kittens', 'off': None, 'on': 'https://www.loc.gov/manuscripts/?fo=json&q=kittens', 'title': 'manuscript/mixed material'}, {'count': 173, 'not': 'https://www.loc.gov/search/?fa=original-format!:web+page&fo=json&q=kittens', 'off': None, 'on': 'https://www.loc.gov/search/?fa=original-format:web+page&fo=json&q=kittens', 'title': 'web page'}, {'count': 144, 'not': 'https://www.loc.gov/search/?fa=original-format!:photo,+print,+drawing&fo=json&q=kittens', 'off': None, 'on': 'https://www.loc.gov/photos/?fo=json&q=kittens', 'title': 'photo, print, drawing'}, {'count': 59, 'not': 'https://www.loc.gov/search/?fa=original-format!:film,+video&fo=json&q=kittens', 'off': None, 'on': 'https://www.loc.gov/film-and-videos/?fo=json&q=kittens', 'title': 'film, video'}, {'count': 28, 'not': 'https://www.loc.gov/search/?fa=original-format!:legislation&fo=json&q=kittens', 'off': None, 'on': 'https://www.loc.gov/search/?fa=original-format:legislation&fo=json&q=kittens', 'title': 'legislation'}, {'count': 13, 'not': 'https://www.loc.gov/search/?fa=original-format!:sound+recording&fo=json&q=kittens', 'off': None, 'on': 'https://www.loc.gov/audio/?fo=json&q=kittens', 'title': 'sound recording'}, {'count': 10, 'not': 'https://www.loc.gov/search/?fa=original-format!:notated+music&fo=json&q=kittens', 'off': None, 'on': 'https://www.loc.gov/notated-music/?fo=json&q=kittens', 'title': 'notated music'}, {'count': 6, 'not': 'https://www.loc.gov/search/?fa=original-format!:personal+narrative&fo=json&q=kittens', 'off': None, 'on': 'https://www.loc.gov/search/?fa=original-format:personal+narrative&fo=json&q=kittens', 'title': 'personal narrative'}, {'count': 2, 'not': 'https://www.loc.gov/search/?fa=original-format!:3d+object&fo=json&q=kittens', 'off': None, 'on': 'https://www.loc.gov/search/?fa=original-format:3d+object&fo=json&q=kittens', 'title': '3d object'}, {'count': 1, 'not': 'https://www.loc.gov/search/?fa=original-format!:software,+e-resource&fo=json&q=kittens', 'off': None, 'on': 'https://www.loc.gov/search/?fa=original-format:software,+e-resource&fo=json&q=kittens', 'title': 'software, e-resource'}], 'title': 'Original Format', 'type': 'original-format'}, {'filters': [{'count': 179472, 'not': 'https://www.loc.gov/search/?fa=online-format!:image&fo=json&q=kittens',  ...

# %%
response_json = requests.get(baseURL + endpoint, params={'q':'castles','fo':'json'}).json()

print(response_json)
# Out:
# {'breadcrumbs': [{'Library of Congress': 'https://www.loc.gov'}, {'Search': 'https://www.loc.gov/search/?fo=json&q=castles'}], 'expert_resources': None, 'facet_trail': [{'facet': 'searchTerms', 'field': 'searchTerms', 'superset': 'https://www.loc.gov/search/?fo=json', 'value': 'castles'}, {'facet': 'Available Online', 'field': 'digitized', 'superset': 'https://www.loc.gov/search/?all=true&fo=json&q=castles', 'value': 'digitized'}], 'facet_views': {'calendar': 'https://www.loc.gov/search/?fo=json&fs=calendar&q=castles', 'chart': 'https://www.loc.gov/search/?fo=json&fs=chart&q=castles', 'current': 'list', 'list': 'https://www.loc.gov/search/?fo=json&q=castles'}, 'facets': [{'filters': [{'count': 931042, 'not': None, 'off': None, 'on': 'https://www.loc.gov/search/?fo=json&q=castles', 'title': 'true'}, {'count': 23459, 'not': None, 'off': None, 'on': 'https://www.loc.gov/search/?all=true&fo=json&q=castles', 'title': 'false'}], 'title': 'Available Online', 'type': 'digitized'}, {'filters': [{'count': 865591, 'not': 'https://www.loc.gov/search/?fa=original-format!:newspaper&fo=json&q=castles', 'off': None, 'on': 'https://www.loc.gov/newspapers/?dl=item&fo=json&q=castles', 'title': 'newspaper'}, {'count': 53389, 'not': 'https://www.loc.gov/search/?fa=original-format!:book&fo=json&q=castles', 'off': None, 'on': 'https://www.loc.gov/books/?fo=json&q=castles', 'title': 'book'}, {'count': 5369, 'not': 'https://www.loc.gov/search/?fa=original-format!:photo,+print,+drawing&fo=json&q=castles', 'off': None, 'on': 'https://www.loc.gov/photos/?fo=json&q=castles', 'title': 'photo, print, drawing'}, {'count': 2695, 'not': 'https://www.loc.gov/search/?fa=original-format!:periodical&fo=json&q=castles', 'off': None, 'on': 'https://www.loc.gov/search/?fa=original-format:periodical&fo=json&q=castles', 'title': 'periodical'}, {'count': 2459, 'not': 'https://www.loc.gov/search/?fa=original-format!:manuscript/mixed+material&fo=json&q=castles', 'off': None, 'on': 'https://www.loc.gov/manuscripts/?fo=json&q=castles', 'title': 'manuscript/mixed material'}, {'count': 1382, 'not': 'https://www.loc.gov/search/?fa=original-format!:web+page&fo=json&q=castles', 'off': None, 'on': 'https://www.loc.gov/search/?fa=original-format:web+page&fo=json&q=castles', 'title': 'web page'}, {'count': 576, 'not': 'https://www.loc.gov/search/?fa=original-format!:film,+video&fo=json&q=castles', 'off': None, 'on': 'https://www.loc.gov/film-and-videos/?fo=json&q=castles', 'title': 'film, video'}, {'count': 548, 'not': 'https://www.loc.gov/search/?fa=original-format!:legislation&fo=json&q=castles', 'off': None, 'on': 'https://www.loc.gov/search/?fa=original-format:legislation&fo=json&q=castles', 'title': 'legislation'}, {'count': 397, 'not': 'https://www.loc.gov/search/?fa=original-format!:personal+narrative&fo=json&q=castles', 'off': None, 'on': 'https://www.loc.gov/search/?fa=original-format:personal+narrative&fo=json&q=castles', 'title': 'personal narrative'}, {'count': 160, 'not': 'https://www.loc.gov/search/?fa=original-format!:sound+recording&fo=json&q=castles', 'off': None, 'on': 'https://www.loc.gov/audio/?fo=json&q=castles', 'title': 'sound recording'}, {'count': 142, 'not': 'https://www.loc.gov/search/?fa=original-format!:map&fo=json&q=castles', 'off': None, 'on': 'https://www.loc.gov/maps/?fo=json&q=castles', 'title': 'map'}, {'count': 94, 'not': 'https://www.loc.gov/search/?fa=original-format!:notated+music&fo=json&q=castles', 'off': None, 'on': 'https://www.loc.gov/notated-music/?fo=json&q=castles', 'title': 'notated music'}, {'count': 43, 'not': 'https://www.loc.gov/search/?fa=original-format!:software,+e-resource&fo=json&q=castles', 'off': None, 'on': 'https://www.loc.gov/search/?fa=original-format:software,+e-resource&fo=json&q=castles', 'title': 'software, e-resource'}, {'count': 30, 'not': 'https://www.loc.gov/search/?fa=original-format!:3d+object&fo=json&q=castles', 'off': None, 'on': 'https://www.loc.gov/search/?fa=original-format:3d+object&fo=json&q=castles', ' ...

# %%
for key in response_json:
    print(key)
# Out:
# breadcrumbs
# expert_resources
# facet_trail
# facet_views
# facets
# form_facets
# options
# pagination
# results
# search
# timestamp
# views

# %%
response_json['results']
# Out:
# [{'access_restricted': False,
#   'aka': ['http://www.loc.gov/pictures/collection/pgz/item/2002696569/',
#    'http://www.loc.gov/item/2002696569/',
#    'http://www.loc.gov/pictures/item/2002696569/',
#    'https://hdl.loc.gov/loc.pnp/ppmsc.08198',
#    'http://www.loc.gov/resource/ppmsc.08198/',
#    'http://lccn.loc.gov/2002696569'],
#   'campaigns': [],
#   'date': '1890-01-01',
#   'dates': ['1890'],
#   'description': ['1 photomechanical print : photochrom, color. | Image shows Corfe Castle, on the Isle of Purbeck, Dorset, England. (Source: Flickr Commons project, 2013)'],
#   'digitized': True,
#   'extract_timestamp': '2021-09-01T22:59:38.281Z',
#   'group': ['pgz',
#    'catalog-split-13',
#    'catalog',
#    'photochrom',
#    'main-catalog-split-13',
#    'main-catalog'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/2002696569/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/pnp/ppmsc/08100/08198_150px.jpg#h=112&w=150',
#    'https://tile.loc.gov/storage-services/service/pnp/ppmsc/08100/08198t.gif#h=112&w=150',
#    'https://tile.loc.gov/storage-services/service/pnp/ppmsc/08100/08198r.jpg#h=477&w=640',
#    'https://tile.loc.gov/storage-services/service/pnp/ppmsc/08100/08198v.jpg#h=763&w=1024'],
#   'index': 1,
#   'item': {'call_number': 'LOT 13415, no. 220 [item] [P&P]',
#    'control_number': '2002696569',
#    'created': '2016-04-21 06:19:13',
#    'created_published': '[between ca. 1890 and ca. 1900].',
#    'created_published_date': '[between ca. 1890 and ca. 1900].',
#    'date': '[between ca. 1890 and ca. 1900].',
#    'digital_id': ['ppmsc 08198 //hdl.loc.gov/loc.pnp/ppmsc.08198'],
#    'display_offsite': True,
#    'format': ['still image'],
#    'formats': [{'link': '//www.loc.gov/pictures/related/?fi=format&q=Photochrom%20prints--Color--1890-1900.&co=pgz',
#      'title': 'Photochrom prints--Color--1890-1900.'}],
#    'genre': ['Photochrom prints--Color--1890-1900'],
#    'id': '2002696569',
#    'link': '//www.loc.gov/pictures/item/2002696569/',
#    'marc': '//www.loc.gov/pictures/item/2002696569/marc/',
#    'medium': ['1 photomechanical print : photochrom, color.'],
#    'medium_brief': '1 photomechanical print :',
#    'mediums': ['1 photomechanical print : photochrom, color.'],
#    'modified': '2016-04-21 06:19:13',
#    'notes': ['Title from the Detroit Publishing Co., Catalogue J foreign section, Detroit, Mich. : Detroit Publishing Company, 1905.',
#     'Print no. "10322".',
#     'More information about the Photochrom Print Collection is available at http://hdl.loc.gov/loc.pnp/pp.pgz',
#     'Forms part of: Views of the British Isles, in the Photochrom print collection.'],
#    'number_former_id': ['https://www.loc.gov/item/2002696569',
#     'https://www.loc.gov/item/12710347'],
#    'part_of': 'Views of the British Isles',
#    'place': [{'latitude': '',
#      'link': '//www.loc.gov/pictures/related/?fi=place&q=England--Corfe%20Castle&co=pgz',
#      'longitude': '',
#      'title': 'England--Corfe Castle'}],
#    'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print',
#    'reproduction_number': 'LC-DIG-ppmsc-08198 (digital file from original)',
#    'resource_links': ['//hdl.loc.gov/loc.pnp/ppmsc.08198'],
#    'rights_advisory': 'No known restrictions on reproduction.',
#    'rights_information': 'No known restrictions on reproduction.',
#    'service_low': 'https://tile.loc.gov/storage-services/service/pnp/ppmsc/08100/08198_150px.jpg',
#    'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/ppmsc/08100/08198r.jpg',
#    'sort_date': '1890',
#    'source_collection': ['Views of the British Isles'],
#    'source_created': '2002-03-19 00:00:00',
#    'source_modified': '2014-04-02 12:13:02',
#    'subject_headings': ['England--Corfe Castle.',
#     'Corfe Castle (Corfe Castle, England)',
#     'England--Corfe Castle'],
#    'subjects': ['England--Corfe Castle',
#     'Corfe Castle (Corfe Castle, England)'],
#    'summary': 'Image shows Corfe Castle, on the Isle of Purbeck, Dorset, England. (Source: Flickr Commons project, 2013)',
#    'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/ppmsc/08100/08198_150px.jpg',
#    'title': '[Castle, Corfe Castle, England]'},
#   'language': ['english'],
#   'location': ['england', 'corfe castle'],
#   'location_city': ['corfe castle'],
#   'location_country': ['england'],
#   'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#   'number': ['http://www.loc.gov/item/12710347',
#    'http://www.loc.gov/item/2002696569',
#    '2014-04-02t12:13:02',
#    '2002696569'],
#   'number_former_id': ['http://www.loc.gov/item/2002696569',
#    'http://www.loc.gov/item/12710347'],
#   'number_lccn': ['2002696569'],
#   'number_source_modified': ['2014-04-02t12:13:02'],
#   'online_format': ['image'],
#   'original_format': ['photo, print, drawing'],
#   'partof': ['prints & photographs online catalog (library of congress)',
#    'catalog',
#    'lot 13415',
#    'photochrom prints',
#    'prints and photographs division'],
#   'related': {'group_record': '//www.loc.gov/pictures/search/?q=LOT 13415&fi=number&op=PHRASE&va=exact&co=coll&sg=true',
#    'neighbors': '//www.loc.gov/pictures/related/?&co=pgz&pk=2002696569&st=gallery&sb=call_number#focus'},
#   'reproductions': '<p>If an image is displaying, you can download it yourself. (Some images \r\ndisplay only as thumbnails outside the Library of Congress because of rights \r\nconsiderations, but you have access to larger size images on site.)\r\n</p>\r\n\r\n<p>  \r\nAlternatively, you can purchase copies of various types through Library \r\nof Congress Duplication Services</a>.\r\n</p>\r\n\r\n<p> \r\n<ol>\r\n<p>\r\n<li><strong>If a digital image is displaying:</strong> The qualities of the digital image \r\npartially depend on whether it was made from the original or an \r\nintermediate such as a copy negative or transparency. If the Reproduction \r\nNumber field above includes a reproduction number that starts with \r\nLC-DIG..., then there is a digital image that was made directly \r\nfrom the original and is of sufficient resolution for most publication\r\n purposes.\r\n</li> \r\n</p>\r\n\r\n<li><strong>If there is information listed in the Reproduction Number field above:</strong> \r\nYou can use the reproduction number to purchase a copy from Duplication \r\nServices.  It will be made from the source listed in the parentheses after\r\n the number.  \r\n<p> \r\nIf only black-and-white (&quot;b&w&quot;) sources are listed and you \r\n desire a copy showing color or tint (assuming the original has any), \r\n you can generally purchase a quality copy of the original in color by \r\n citing the Call Number listed above and including the catalog record \r\n (&quot;About This Item&quot;) with your request.\r\n </p>\r\n</li>\r\n\r\n<li><strong>If there is no information listed in the Reproduction Number field \r\nabove:</strong> You can generally purchase a quality copy through \r\nDuplication Services. Cite the Call Number listed above and include the catalog record (&quot;About This Item&quot;) with \r\n your request.\r\n</li>\r\n</ol>\r\n</p>\r\n\r\n<p> \r\nPrice lists, contact information, and order forms are available on the\r\n <a href="//lcweb.loc.gov/preserv/pds/">Duplication Services Web site</a>.  \r\n</p>\r\n\r\n\r\n\r\n',
#   'resources': [{'caption': 'digital file from  original',
#     'files': 1,
#     'image': 'https://tile.loc.gov/storage-services/service/pnp/ppmsc/08100/08198_150px.jpg',
#     'url': 'https://www.loc.gov/resource/ppmsc.08198/'}],
#   'shelf_id': 'LOT 13415, no. 220 [item] [P&P]',
#   'site': ['pictures', 'catalog'],
#   'subject': ['england',
#    'color',
#    'corfe castle (corfe castle, england)',
#    'photochrom prints',
#    'corfe castle'],
#   'timestamp': '2022-04-30T21:56:05.214Z',
#   'title': '[Castle, Corfe Castle, England]',
#   'unrestricted': True,
#   'url': 'https://www.loc.gov/item/2002696569/'},
#  {'access_restricted': False,
#   'aka': ['https://www.loc.gov/pictures/item/2017659169/',
#    'http://www.loc.gov/item/2017659169/',
#    'http://www.loc.gov/pictures/item/2017659169/',
#    'https://www.loc.gov/pictures/collection/cph/item/2017659169/',
#    'http://www.loc.gov/pictures/collection/cph/item/2017659169/',
#    'http://www.loc.gov/resource/ppmsca.52346/',
#    'http://www.loc.gov/pictures/collection/pgz/item/2017659169/',
#    'https://hdl.loc.gov/loc.pnp/ppmsca.52346',
#    'http://lccn.loc.gov/2017659169'],
#   'campaigns': [],
#   'contributor': ['photoglob co.'],
#   'date': '1890-01-01',
#   'dates': ['1890'],
#   'description': ['1 print : color photochrom ; sheet 17 x  23 cm.'],
#   'digitized': True,
#   'extract_timestamp': '2021-08-25T02:08:06.863Z',
#   'group': ['cph',
#    'pgz',
#    'catalog-split-14',
#    'catalog',
#    'miscellaneous-items-high-demand',
#    'photochrom',
#    'main-catalog-split-14',
#    'main-catalog'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/2017659169/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/pnp/ppmsca/52300/52346_150px.jpg#h=111&w=150',
#    'https://tile.loc.gov/storage-services/service/pnp/ppmsca/52300/52346r.jpg#h=472&w=640',
#    'https://tile.loc.gov/storage-services/service/pnp/ppmsca/52300/52346v.jpg#h=755&w=1024'],
#   'index': 2,
#   'item': {'call_number': 'LOT 14184, no. 79 [item] [P&P]',
#    'contributors': ['Photoglob Co., publisher.'],
#    'control_number': '2017659169',
#    'created': '2017-09-05T03:40:08Z',
#    'created_published': '[Zürich, Switzerland] : [Photoglob Company], [ca. 1890-1906]',
#    'created_published_date': '[ca. 1890-1906]',
#    'creators': [{'link': 'https://www.loc.gov/pictures/related/?fi=name&q=Photoglob%20Co.&co=cph',
#      'role': 'publisher',
#      'title': 'Photoglob Co.'}],
#    'date': '[ca. 1890-1906]',
#    'digital_id': ['ppmsca 52346 //hdl.loc.gov/loc.pnp/ppmsca.52346'],
#    'display_offsite': True,
#    'format': ['still image'],
#    'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Photochrom%20prints--Color.&co=cph',
#      'title': 'Photochrom prints--Color.'}],
#    'genre': ['Photochrom prints--Color'],
#    'id': '2017659169',
#    'link': 'https://www.loc.gov/pictures/item/2017659169/',
#    'marc': 'https://www.loc.gov/pictures/item/2017659169/marc/',
#    'medium': ['1 print : color photochrom ; sheet 17 x  23 cm.'],
#    'medium_brief': '1 print :',
#    'mediums': ['1 print : color photochrom ; sheet 17 x  23 cm.'],
#    'modified': '2017-09-05T03:40:08Z',
#    'notes': ['Title from item.',
#     'Title in Detroit Publishing Co., Catalogue J foreign section, Detroit, Mich. : Detroit Publishing Company, 1905: "Great Britain and Ireland. Banbury. The Castle."',
#     'Print no. "11418."',
#     'Purchase; Detroit Publishing Company; 1906; 42865.',
#     'Item removed from FOREIGN GEOG FILE - England Barnard in 2017.',
#     'More information about the Photochrom Print Collection is available at  http://hdl.loc.gov/loc.pnp/pp.pgz',
#     'Forms part of: Photochrom Print Collection.'],
#    'other_control_numbers': ['19758854'],
#    'place': [{'latitude': '',
#      'link': 'https://www.loc.gov/pictures/related/?fi=place&q=Great%20Britain--England--Barnard%20Castle&co=cph',
#      'longitude': '',
#      'title': 'Great Britain--England--Barnard Castle'}],
#    'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print',
#    'reproduction_number': 'LC-DIG-ppmsca-52346 (digital file from original item)',
#    'resource_links': ['//hdl.loc.gov/loc.pnp/ppmsca.52346'],
#    'rights_advisory': 'No known restrictions on publication.',
#    'rights_information': 'No known restrictions on publication.',
#    'service_low': 'https://tile.loc.gov/storage-services/service/pnp/ppmsca/52300/52346_150px.jpg',
#    'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/ppmsca/52300/52346r.jpg',
#    'sort_date': '1890',
#    'source_created': '2017-06-27T00:00:00Z',
#    'source_modified': '2017-08-29T09:03:42Z',
#    'subject_headings': ['Barnard Castle (Barnard Castle, England)',
#     'Castles & palaces.',
#     'Ruins.',
#     'Great Britain--England--Barnard Castle.',
#     'Great Britain--England--Barnard Castle'],
#    'subjects': ['Barnard Castle (Barnard Castle, England)',
#     'Castles & palaces',
#     'Ruins',
#     'Great Britain--England--Barnard Castle'],
#    'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/ppmsca/52300/52346_150px.jpg',
#    'title': 'Barnard Castle. The Castle'},
#   'language': ['english'],
#   'location': ['england', 'great britain', 'barnard castle'],
#   'location_city': ['barnard castle'],
#   'location_country': ['great britain'],
#   'location_state': ['england'],
#   'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#   'number': ['http://www.loc.gov/item/19758854',
#    '2017659169',
#    'sheet',
#    '2017-08-29t09:03:42'],
#   'number_carrier_type': ['sheet'],
#   'number_former_id': ['http://www.loc.gov/item/19758854'],
#   'number_lccn': ['2017659169'],
#   'number_source_modified': ['2017-08-29t09:03:42'],
#   'online_format': ['image'],
#   'original_format': ['photo, print, drawing'],
#   'partof': ['prints & photographs online catalog (library of congress)',
#    'catalog',
#    'miscellaneous items in high demand',
#    'photochrom prints',
#    'lot 14184',
#    'prints and photographs division'],
#   'related': {'group_record': 'https://www.loc.gov/pictures/search/?q=LOT 14184&fi=number&op=PHRASE&va=exact&co=coll&sg=true',
#    'neighbors': 'https://www.loc.gov/pictures/related/?&co=cph&pk=2017659169&st=gallery&sb=call_number#focus'},
#   'reproductions': '<p>If an image is displaying, you can download it yourself. (Some images \ndisplay only as thumbnails outside the Library of Congress because of rights \nconsiderations, but you have access to larger size images on site.)\n</p>\n\n<p>  \nAlternatively, you can purchase copies of various types through Library \nof Congress Duplication Services</a>.\n</p>\n\n<p> \n<ol>\n<p>\n<li><strong>If a digital image is displaying:</strong> The qualities of the digital image \npartially depend on whether it was made from the original or an \nintermediate such as a copy negative or transparency. If the Reproduction \nNumber field above includes a reproduction number that starts with \nLC-DIG..., then there is a digital image that was made directly \nfrom the original and is of sufficient resolution for most publication\n purposes.\n</li> \n</p>\n\n<li><strong>If there is information listed in the Reproduction Number field above:</strong> \nYou can use the reproduction number to purchase a copy from Duplication \nServices.  It will be made from the source listed in the parentheses after\n the number.  \n<p> \nIf only black-and-white (&quot;b&w&quot;) sources are listed and you \n desire a copy showing color or tint (assuming the original has any), \n you can generally purchase a quality copy of the original in color by \n citing the Call Number listed above and including the catalog record \n (&quot;About This Item&quot;) with your request.\n </p>\n</li>\n\n<li><strong>If there is no information listed in the Reproduction Number field \nabove:</strong> You can generally purchase a quality copy through \nDuplication Services. Cite the Call Number listed above and include the catalog record (&quot;About This Item&quot;) with \n your request.\n</li>\n</ol>\n</p>\n\n<p> \nPrice lists, contact information, and order forms are available on the\n <a href="//www.loc.gov/duplicationservices/">Duplication Services Web site</a>.  \n</p>\n\n\n\n',
#   'resources': [{'caption': 'digital file from original item',
#     'files': 1,
#     'image': 'https://tile.loc.gov/storage-services/service/pnp/ppmsca/52300/52346_150px.jpg',
#     'url': 'https://www.loc.gov/resource/ppmsca.52346/'}],
#   'shelf_id': 'LOT 14184, no. 79 [item] [P&P]',
#   'site': ['pictures', 'catalog'],
#   'subject': ['england',
#    'great britain',
#    'castles & palaces',
#    'barnard castle',
#    'ruins',
#    'color',
#    'barnard castle (barnard castle, england)',
#    'photochrom prints'],
#   'timestamp': '2022-05-02T07:59:26.320Z',
#   'title': 'Barnard Castle. The Castle',
#   'unrestricted': True,
#   'url': 'https://www.loc.gov/item/2017659169/'},
#  {'access_restricted': False,
#   'aka': ['https://www.loc.gov/pictures/item/94512965/',
#    'http://www.loc.gov/item/94512965/',
#    'http://www.loc.gov/pictures/item/94512965/',
#    'https://www.loc.gov/pictures/collection/cph/item/94512965/',
#    'http://www.loc.gov/pictures/collection/cph/item/94512965/',
#    'http://www.loc.gov/resource/cph.3c09095/',
#    'http://lccn.loc.gov/94512965',
#    'https://hdl.loc.gov/loc.pnp/cph.3c09095'],
#   'campaigns': [],
#   'date': '1860-01-01',
#   'dates': ['1860'],
#   'description': ['1 photographic print : albumen. | Rear view of Edinburgh Castle as seen from the street.'],
#   'digitized': True,
#   'extract_timestamp': '2021-08-24T21:59:25.374Z',
#   'group': ['cph',
#    'catalog-split-09',
#    'catalog',
#    'miscellaneous-items-high-demand',
#    'main-catalog-split-09',
#    'main-catalog'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/94512965/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/pnp/cph/3c00000/3c09000/3c09000/3c09095_150px.jpg#h=121&w=150',
#    'https://tile.loc.gov/storage-services/service/pnp/cph/3c00000/3c09000/3c09000/3c09095t.gif#h=121&w=150',
#    'https://tile.loc.gov/storage-services/service/pnp/cph/3c00000/3c09000/3c09000/3c09095r.jpg#h=517&w=640',
#    'https://tile.loc.gov/storage-services/service/pnp/cph/3c00000/3c09000/3c09000/3c09095v.jpg#h=828&w=1024'],
#   'index': 3,
#   'item': {'call_number': 'LOT 7739 <item> [P&P]',
#    'control_number': '94512965',
#    'created': '2016-04-20T09:38:31Z',
#    'created_published': '[between 1860 and 1890]',
#    'created_published_date': '[between 1860 and 1890]',
#    'date': '[between 1860 and 1890]',
#    'digital_id': ['cph 3c09095 //hdl.loc.gov/loc.pnp/cph.3c09095'],
#    'display_offsite': True,
#    'format': ['still image'],
#    'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Albumen%20prints--1860-1890.&co=cph',
#      'title': 'Albumen prints--1860-1890.'}],
#    'genre': ['Albumen prints--1860-1890'],
#    'id': '94512965',
#    'link': 'https://www.loc.gov/pictures/item/94512965/',
#    'location': ['Scotland--Edinburgh'],
#    'marc': 'https://www.loc.gov/pictures/item/94512965/marc/',
#    'medium': ['1 photographic print : albumen.'],
#    'medium_brief': '1 photographic print :',
#    'mediums': ['1 photographic print : albumen.'],
#    'modified': '2016-04-20T09:38:31Z',
#    'notes': ['In album: Prague, Innsbruck, Munich, Nuremberg, Dresden, Berlin, Hombourg, Edinburgh, opposite p. 196.',
#     'No. 372.'],
#    'number_former_id': ['https://www.loc.gov/item/94512965',
#     'https://www.loc.gov/item/11640156'],
#    'other_control_numbers': ['11640156'],
#    'place': [{'latitude': '',
#      'link': 'https://www.loc.gov/pictures/related/?fi=place&q=Scotland--Edinburgh&co=cph',
#      'longitude': '',
#      'title': 'Scotland--Edinburgh'}],
#    'reproduction_number': 'LC-USZ62-109095 (b&w film copy neg.)',
#    'resource_links': ['//hdl.loc.gov/loc.pnp/cph.3c09095'],
#    'rights_advisory': "No known restrictions on publication in the United States.  Use elsewhere may be restricted by other countries' laws.",
#    'rights_information': "No known restrictions on publication in the United States.  Use elsewhere may be restricted by other countries' laws.",
#    'service_low': 'https://tile.loc.gov/storage-services/service/pnp/cph/3c00000/3c09000/3c09000/3c09095_150px.jpg',
#    'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/cph/3c00000/3c09000/3c09000/3c09095r.jpg',
#    'sort_date': '1860',
#    'source_created': '1994-11-14T00:00:00Z',
#    'source_modified': '2005-02-14T11:51:48Z',
#    'subject_headings': ['Edinburgh Castle (Edinburgh, Scotland)',
#     'Castles & palaces--Scotland--Edinburgh--1860-1890.',
#     'Commercial streets--Scotland--Edinburgh--1860-1890.',
#     'Scotland--Edinburgh'],
#    'subjects': ['Edinburgh Castle (Edinburgh, Scotland)',
#     'Castles & palaces--Scotland--Edinburgh--1860-1890',
#     'Commercial streets--Scotland--Edinburgh--1860-1890'],
#    'summary': 'Rear view of Edinburgh Castle as seen from the street.',
#    'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/cph/3c00000/3c09000/3c09000/3c09095_150px.jpg',
#    'title': 'Edinburgh. Castle'},
#   'language': ['english'],
#   'location': ['edinburgh', 'scotland'],
#   'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#   'number': ['http://www.loc.gov/item/11640156',
#    'http://www.loc.gov/item/94512965',
#    '94512965',
#    '2005-02-14t11:51:48'],
#   'number_former_id': ['http://www.loc.gov/item/11640156',
#    'http://www.loc.gov/item/94512965'],
#   'number_lccn': ['94512965'],
#   'number_source_modified': ['2005-02-14t11:51:48'],
#   'online_format': ['image'],
#   'original_format': ['photo, print, drawing'],
#   'partof': ['prints & photographs online catalog (library of congress)',
#    'catalog',
#    'lot 7739',
#    'miscellaneous items in high demand',
#    'prints and photographs division'],
#   'related': {'group_record': 'https://www.loc.gov/pictures/search/?q=LOT 7739&fi=number&op=PHRASE&va=exact&co=coll&sg=true',
#    'neighbors': 'https://www.loc.gov/pictures/related/?&co=cph&pk=94512965&st=gallery&sb=call_number#focus'},
#   'reproductions': '<p>If an image is displaying, you can download it yourself. (Some images \ndisplay only as thumbnails outside the Library of Congress because of rights \nconsiderations, but you have access to larger size images on site.)\n</p>\n\n<p>  \nAlternatively, you can purchase copies of various types through Library \nof Congress Duplication Services</a>.\n</p>\n\n<p> \n<ol>\n<p>\n<li><strong>If a digital image is displaying:</strong> The qualities of the digital image \npartially depend on whether it was made from the original or an \nintermediate such as a copy negative or transparency. If the Reproduction \nNumber field above includes a reproduction number that starts with \nLC-DIG..., then there is a digital image that was made directly \nfrom the original and is of sufficient resolution for most publication\n purposes.\n</li> \n</p>\n\n<li><strong>If there is information listed in the Reproduction Number field above:</strong> \nYou can use the reproduction number to purchase a copy from Duplication \nServices.  It will be made from the source listed in the parentheses after\n the number.  \n<p> \nIf only black-and-white (&quot;b&w&quot;) sources are listed and you \n desire a copy showing color or tint (assuming the original has any), \n you can generally purchase a quality copy of the original in color by \n citing the Call Number listed above and including the catalog record \n (&quot;About This Item&quot;) with your request.\n </p>\n</li>\n\n<li><strong>If there is no information listed in the Reproduction Number field \nabove:</strong> You can generally purchase a quality copy through \nDuplication Services. Cite the Call Number listed above and include the catalog record (&quot;About This Item&quot;) with \n your request.\n</li>\n</ol>\n</p>\n\n<p> \nPrice lists, contact information, and order forms are available on the\n <a href="//www.loc.gov/duplicationservices/">Duplication Services Web site</a>.  \n</p>\n\n\n\n',
#   'resources': [{'caption': 'b&w film copy neg.',
#     'files': 1,
#     'image': 'https://tile.loc.gov/storage-services/service/pnp/cph/3c00000/3c09000/3c09000/3c09095_150px.jpg',
#     'url': 'https://www.loc.gov/resource/cph.3c09095/'}],
#   'shelf_id': 'LOT 7739 <item> [P&P]',
#   'site': ['pictures', 'catalog'],
#   'subject': ['edinburgh',
#    'castles & palaces',
#    'commercial streets',
#    'scotland',
#    'albumen prints',
#    'edinburgh castle (edinburgh, scotland)'],
#   'timestamp': '2022-05-02T12:21:24.047Z',
#   'title': 'Edinburgh. Castle',
#   'unrestricted': True,
#   'url': 'https://www.loc.gov/item/94512965/'},
#  {'access_restricted': False,
#   'aka': ['https://www.loc.gov/pictures/item/96513047/',
#    'http://www.loc.gov/item/96513047/',
#    'http://www.loc.gov/pictures/item/96513047/',
#    'https://www.loc.gov/pictures/collection/cph/item/96513047/',
#    'http://www.loc.gov/pictures/collection/cph/item/96513047/',
#    'http://www.loc.gov/resource/ppmsca.52369/',
#    'http://www.loc.gov/resource/cph.3g04768/',
#    'http://www.loc.gov/pictures/collection/pgz/item/96513047/',
#    'https://hdl.loc.gov/loc.pnp/cph.3g04768',
#    'https://hdl.loc.gov/loc.pnp/ppmsca.52369',
#    'http://lccn.loc.gov/96513047'],
#   'campaigns': [],
#   'date': '1890-01-01',
#   'dates': ['1890'],
#   'description': ["1 photomechanical print : photochrom, color. | Bird's-eye view of Corfe Castle on hill, on Isle of Purbeck, England."],
#   'digitized': True,
#   'extract_timestamp': '2021-08-25T02:05:11.574Z',
#   'group': ['cph',
#    'pgz',
#    'catalog-split-03',
#    'catalog',
#    'miscellaneous-items-high-demand',
#    'photochrom',
#    'main-catalog-split-03',
#    'main-catalog'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/96513047/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/pnp/ppmsca/52300/52369_150px.jpg#h=110&w=150',
#    'https://tile.loc.gov/storage-services/service/pnp/ppmsca/52300/52369r.jpg#h=471&w=640',
#    'https://tile.loc.gov/storage-services/service/pnp/ppmsca/52300/52369v.jpg#h=753&w=1024'],
#   'index': 4,
#   'item': {'call_number': 'LOT 14184, no. 102 [item] [P&P]',
#    'control_number': '96513047',
#    'created': '2017-09-26T05:22:48Z',
#    'created_published': '[between 1890 and 1900]',
#    'created_published_date': '[between 1890 and 1900]',
#    'date': '[between 1890 and 1900]',
#    'digital_id': ['ppmsca 52369 //hdl.loc.gov/loc.pnp/ppmsca.52369',
#     'cph 3g04768 //hdl.loc.gov/loc.pnp/cph.3g04768'],
#    'display_offsite': True,
#    'format': ['still image'],
#    'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Bird%27s-eye%20view%20prints--1890-1900.&co=cph',
#      'title': "Bird's-eye view prints--1890-1900."},
#     {'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Photochrom%20prints--Color--1890-1900.&co=cph',
#      'title': 'Photochrom prints--Color--1890-1900.'}],
#    'genre': ["Bird's-eye view prints--1890-1900",
#     'Photochrom prints--Color--1890-1900'],
#    'id': '96513047',
#    'link': 'https://www.loc.gov/pictures/item/96513047/',
#    'location': ['England--Isle of Purbeck'],
#    'marc': 'https://www.loc.gov/pictures/item/96513047/marc/',
#    'medium': ['1 photomechanical print : photochrom, color.'],
#    'medium_brief': '1 photomechanical print :',
#    'mediums': ['1 photomechanical print : photochrom, color.'],
#    'modified': '2017-09-26T05:22:49Z',
#    'notes': ['No. 10322.',
#     'Item removed from FOREIGN GEOG FILE - England Corfe Castle in 2017.',
#     'More information about the Photochrom Print Collection is available at  http://hdl.loc.gov/loc.pnp/pp.pgz',
#     'Forms part of: Photochrom Print Collection.'],
#    'number_former_id': ['https://www.loc.gov/item/96513047',
#     'https://www.loc.gov/item/11677446'],
#    'other_control_numbers': ['11677446'],
#    'place': [{'latitude': '',
#      'link': 'https://www.loc.gov/pictures/related/?fi=place&q=England--Isle%20of%20Purbeck&co=cph',
#      'longitude': '',
#      'title': 'England--Isle of Purbeck'}],
#    'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA',
#    'reproduction_number': 'LC-DIG-ppmsca-52369 (digital file from original item)\nLC-USZC4-4768 (color film copy transparency)',
#    'resource_links': ['//hdl.loc.gov/loc.pnp/ppmsca.52369',
#     '//hdl.loc.gov/loc.pnp/cph.3g04768'],
#    'rights_advisory': 'No known restrictions on publication.',
#    'rights_information': 'No known restrictions on publication.',
#    'service_low': 'https://tile.loc.gov/storage-services/service/pnp/ppmsca/52300/52369_150px.jpg',
#    'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/ppmsca/52300/52369r.jpg',
#    'sort_date': '1890',
#    'source_created': '1996-07-03T00:00:00Z',
#    'source_modified': '2017-09-20T09:33:28Z',
#    'subject_headings': ['Islands--England--Isle of Purbeck--1890-1900.',
#     'Castles & palaces--England--Isle of Purbeck--1890-1900.',
#     'Corfe Castle (Corfe Castle, England)',
#     'England--Isle Of Purbeck'],
#    'subjects': ['Islands--England--Isle of Purbeck--1890-1900',
#     'Castles & palaces--England--Isle of Purbeck--1890-1900',
#     'Corfe Castle (Corfe Castle, England)'],
#    'summary': "Bird's-eye view of Corfe Castle on hill, on Isle of Purbeck, England.",
#    'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/ppmsca/52300/52369_150px.jpg',
#    'title': 'Corfe Castle'},
#   'language': ['english'],
#   'location': ['isle of purbeck', 'england'],
#   'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#   'number': ['http://www.loc.gov/item/11677446',
#    '96513047',
#    '2017-09-20t09:33:28',
#    'http://www.loc.gov/item/96513047'],
#   'number_former_id': ['http://www.loc.gov/item/11677446',
#    'http://www.loc.gov/item/96513047'],
#   'number_lccn': ['96513047'],
#   'number_source_modified': ['2017-09-20t09:33:28'],
#   'online_format': ['image'],
#   'original_format': ['photo, print, drawing'],
#   'partof': ['prints & photographs online catalog (library of congress)',
#    'catalog',
#    'miscellaneous items in high demand',
#    'photochrom prints',
#    'lot 14184',
#    'prints and photographs division'],
#   'related': {'group_record': 'https://www.loc.gov/pictures/search/?q=LOT 14184&fi=number&op=PHRASE&va=exact&co=coll&sg=true',
#    'neighbors': 'https://www.loc.gov/pictures/related/?&co=cph&pk=96513047&st=gallery&sb=call_number#focus'},
#   'reproductions': '<p>If an image is displaying, you can download it yourself. (Some images \ndisplay only as thumbnails outside the Library of Congress because of rights \nconsiderations, but you have access to larger size images on site.)\n</p>\n\n<p>  \nAlternatively, you can purchase copies of various types through Library \nof Congress Duplication Services</a>.\n</p>\n\n<p> \n<ol>\n<p>\n<li><strong>If a digital image is displaying:</strong> The qualities of the digital image \npartially depend on whether it was made from the original or an \nintermediate such as a copy negative or transparency. If the Reproduction \nNumber field above includes a reproduction number that starts with \nLC-DIG..., then there is a digital image that was made directly \nfrom the original and is of sufficient resolution for most publication\n purposes.\n</li> \n</p>\n\n<li><strong>If there is information listed in the Reproduction Number field above:</strong> \nYou can use the reproduction number to purchase a copy from Duplication \nServices.  It will be made from the source listed in the parentheses after\n the number.  \n<p> \nIf only black-and-white (&quot;b&w&quot;) sources are listed and you \n desire a copy showing color or tint (assuming the original has any), \n you can generally purchase a quality copy of the original in color by \n citing the Call Number listed above and including the catalog record \n (&quot;About This Item&quot;) with your request.\n </p>\n</li>\n\n<li><strong>If there is no information listed in the Reproduction Number field \nabove:</strong> You can generally purchase a quality copy through \nDuplication Services. Cite the Call Number listed above and include the catalog record (&quot;About This Item&quot;) with \n your request.\n</li>\n</ol>\n</p>\n\n<p> \nPrice lists, contact information, and order forms are available on the\n <a href="//www.loc.gov/duplicationservices/">Duplication Services Web site</a>.  \n</p>\n\n\n\n',
#   'resources': [{'caption': 'digital file from original item',
#     'files': 1,
#     'image': 'https://tile.loc.gov/storage-services/service/pnp/ppmsca/52300/52369_150px.jpg',
#     'url': 'https://www.loc.gov/resource/ppmsca.52369/'},
#    {'caption': 'color film copy transparency',
#     'files': 1,
#     'image': 'https://tile.loc.gov/storage-services/service/pnp/cph/3g00000/3g04000/3g04700/3g04768_150px.jpg',
#     'url': 'https://www.loc.gov/resource/cph.3g04768/'}],
#   'shelf_id': 'LOT 14184, no. 102 [item] [P&P]',
#   'site': ['pictures', 'catalog'],
#   'subject': ["bird's-eye view prints",
#    'isle of purbeck',
#    'england',
#    'castles & palaces',
#    'color',
#    'corfe castle (corfe castle, england)',
#    'islands',
#    'photochrom prints'],
#   'timestamp': '2022-05-02T12:46:29.217Z',
#   'title': 'Corfe Castle',
#   'unrestricted': True,
#   'url': 'https://www.loc.gov/item/96513047/'},
#  {'access_restricted': False,
#   'aka': ['https://www.loc.gov/pictures/item/2004665729/',
#    'http://www.loc.gov/item/2004665729/',
#    'http://www.loc.gov/pictures/item/2004665729/',
#    'https://www.loc.gov/pictures/collection/cph/item/2004665729/',
#    'http://www.loc.gov/pictures/collection/cph/item/2004665729/',
#    'http://www.loc.gov/resource/cph.3b15129/',
#    'http://lccn.loc.gov/2004665729',
#    'https://hdl.loc.gov/loc.pnp/cph.3b15129'],
#   'campaigns': [],
#   'contributor': ['davison, george'],
#   'date': '1909-01-01',
#   'dates': ['1909'],
#   'description': ['1 photomechanical print : photogravure. | Print shows castle in Scotland.'],
#   'digitized': True,
#   'extract_timestamp': '2021-08-25T07:22:12.083Z',
#   'group': ['cph',
#    'catalog-split-09',
#    'catalog',
#    'miscellaneous-items-high-demand',
#    'main-catalog-split-09',
#    'main-catalog'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/2004665729/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/pnp/cph/3b10000/3b15000/3b15100/3b15129_150px.jpg#h=111&w=150',
#    'https://tile.loc.gov/storage-services/service/pnp/cph/3b10000/3b15000/3b15100/3b15129t.gif#h=111&w=150',
#    'https://tile.loc.gov/storage-services/service/pnp/cph/3b10000/3b15000/3b15100/3b15129r.jpg#h=475&w=640'],
#   'index': 5,
#   'item': {'call_number': 'Illus. in TR1.C5 1909 (Case X) [P&P]',
#    'contributors': ['Davison, George, 1854-1930, photographer.'],
#    'control_number': '2004665729',
#    'created': '2016-04-21T10:36:01Z',
#    'created_published': '1909.',
#    'created_published_date': '1909.',
#    'creators': [{'link': 'https://www.loc.gov/pictures/related/?fi=name&q=Davison%2C%20George%2C%201854-1930&co=cph',
#      'role': 'photographer',
#      'title': 'Davison, George, 1854-1930'}],
#    'date': '1909.',
#    'digital_id': ['cph 3b15129 //hdl.loc.gov/loc.pnp/cph.3b15129'],
#    'display_offsite': True,
#    'format': ['still image'],
#    'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Periodical%20illustrations--1900-1910.&co=cph',
#      'title': 'Periodical illustrations--1900-1910.'},
#     {'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Photogravures--1900-1910.&co=cph',
#      'title': 'Photogravures--1900-1910.'}],
#    'genre': ['Periodical illustrations--1900-1910',
#     'Photogravures--1900-1910'],
#    'id': '2004665729',
#    'language': ['eng'],
#    'link': 'https://www.loc.gov/pictures/item/2004665729/',
#    'location': ['Wales'],
#    'marc': 'https://www.loc.gov/pictures/item/2004665729/marc/',
#    'medium': ['1 photomechanical print : photogravure.'],
#    'medium_brief': '1 photomechanical print :',
#    'mediums': ['1 photomechanical print : photogravure.'],
#    'modified': '2016-04-21T10:36:01Z',
#    'notes': ['Illus. in: Camera Work, no. 26, April 1909, plate II.',
#     'Title from item.'],
#    'other_control_numbers': ['13472159'],
#    'place': [{'latitude': '',
#      'link': 'https://www.loc.gov/pictures/related/?fi=place&q=Wales&co=cph',
#      'longitude': '',
#      'title': 'Wales'}],
#    'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print',
#    'reproduction_number': 'LC-USZ62-67657 (b&w film copy neg.)',
#    'resource_links': ['//hdl.loc.gov/loc.pnp/cph.3b15129'],
#    'rights_advisory': 'No known restrictions on publication.',
#    'rights_information': 'No known restrictions on publication.',
#    'service_low': 'https://tile.loc.gov/storage-services/service/pnp/cph/3b10000/3b15000/3b15100/3b15129_150px.jpg',
#    'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/cph/3b10000/3b15000/3b15100/3b15129r.jpg',
#    'sort_date': '1909',
#    'source_created': '2004-01-28T00:00:00Z',
#    'source_modified': '2013-01-02T16:31:54Z',
#    'subject_headings': ['Castles & palaces--Wales--1900-1910.', 'Wales'],
#    'subjects': ['Castles & palaces--Wales--1900-1910'],
#    'summary': 'Print shows castle in Scotland.',
#    'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/cph/3b10000/3b15000/3b15100/3b15129_150px.jpg',
#    'title': 'Harlech Castle'},
#   'language': ['english'],
#   'location': ['wales'],
#   'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#   'number': ['2013-01-02t16:31:54',
#    '2004665729',
#    'http://www.loc.gov/item/13472159'],
#   'number_former_id': ['http://www.loc.gov/item/13472159'],
#   'number_lccn': ['2004665729'],
#   'number_source_modified': ['2013-01-02t16:31:54'],
#   'online_format': ['image'],
#   'original_format': ['photo, print, drawing'],
#   'partof': ['prints & photographs online catalog (library of congress)',
#    'miscellaneous items in high demand',
#    'catalog',
#    'prints and photographs division'],
#   'related': {'neighbors': 'https://www.loc.gov/pictures/related/?&co=cph&pk=2004665729&st=gallery&sb=call_number#focus'},
#   'reproductions': '<p>If an image is displaying, you can download it yourself. (Some images \ndisplay only as thumbnails outside the Library of Congress because of rights \nconsiderations, but you have access to larger size images on site.)\n</p>\n\n<p>  \nAlternatively, you can purchase copies of various types through Library \nof Congress Duplication Services</a>.\n</p>\n\n<p> \n<ol>\n<p>\n<li><strong>If a digital image is displaying:</strong> The qualities of the digital image \npartially depend on whether it was made from the original or an \nintermediate such as a copy negative or transparency. If the Reproduction \nNumber field above includes a reproduction number that starts with \nLC-DIG..., then there is a digital image that was made directly \nfrom the original and is of sufficient resolution for most publication\n purposes.\n</li> \n</p>\n\n<li><strong>If there is information listed in the Reproduction Number field above:</strong> \nYou can use the reproduction number to purchase a copy from Duplication \nServices.  It will be made from the source listed in the parentheses after\n the number.  \n<p> \nIf only black-and-white (&quot;b&w&quot;) sources are listed and you \n desire a copy showing color or tint (assuming the original has any), \n you can generally purchase a quality copy of the original in color by \n citing the Call Number listed above and including the catalog record \n (&quot;About This Item&quot;) with your request.\n </p>\n</li>\n\n<li><strong>If there is no information listed in the Reproduction Number field \nabove:</strong> You can generally purchase a quality copy through \nDuplication Services. Cite the Call Number listed above and include the catalog record (&quot;About This Item&quot;) with \n your request.\n</li>\n</ol>\n</p>\n\n<p> \nPrice lists, contact information, and order forms are available on the\n <a href="//www.loc.gov/duplicationservices/">Duplication Services Web site</a>.  \n</p>\n\n\n\n',
#   'resources': [{'caption': 'digital file from b&w film copy neg.',
#     'files': 1,
#     'image': 'https://tile.loc.gov/storage-services/service/pnp/cph/3b10000/3b15000/3b15100/3b15129_150px.jpg',
#     'url': 'https://www.loc.gov/resource/cph.3b15129/'}],
#   'shelf_id': 'Illus. in TR1.C5 1909 (Case X) [P&P]',
#   'site': ['pictures', 'catalog'],
#   'subject': ['wales',
#    'periodical illustrations',
#    'photogravures',
#    'castles & palaces'],
#   'timestamp': '2022-05-01T21:52:18.155Z',
#   'title': 'Harlech Castle',
#   'unrestricted': True,
#   'url': 'https://www.loc.gov/item/2004665729/'},
#  {'access_restricted': True,
#   'aka': ['https://www.loc.gov/pictures/item/93500178/',
#    'http://www.loc.gov/item/93500178/',
#    'http://www.loc.gov/pictures/item/93500178/',
#    'https://www.loc.gov/pictures/collection/cph/item/93500178/',
#    'http://www.loc.gov/pictures/collection/cph/item/93500178/',
#    'http://www.loc.gov/resource/cph.3g02295/',
#    'http://lccn.loc.gov/93500178',
#    'https://hdl.loc.gov/loc.pnp/cph.3g02295'],
#   'campaigns': [],
#   'date': '1890-01-01',
#   'dates': ['1890'],
#   'description': ['1 photographic print : hand-colored. | Castle at Nagoya, Japan.'],
#   'digitized': True,
#   'extract_timestamp': '2021-08-25T15:27:00.629Z',
#   'group': ['cph',
#    'catalog-split-01',
#    'catalog',
#    'miscellaneous-items-high-demand',
#    'main-catalog-split-01',
#    'main-catalog'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/93500178/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/pnp/cph/3g00000/3g02000/3g02200/3g02295_150px.jpg#h=119&w=150'],
#   'index': 6,
#   'item': {'call_number': 'LOT 6373, no. 62  <item> [P&P]',
#    'control_number': '93500178',
#    'created': '2016-04-21T02:10:04Z',
#    'created_published': '[between 1890 and 1910 (?)]',
#    'created_published_date': '[between 1890 and 1910 (?)]',
#    'date': '[between 1890 and 1910 (?)]',
#    'digital_id': ['cph 3g02295 //hdl.loc.gov/loc.pnp/cph.3g02295'],
#    'format': ['still image'],
#    'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Photographic%20prints--Hand-colored--1890-1910.&co=cph',
#      'title': 'Photographic prints--Hand-colored--1890-1910.'}],
#    'genre': ['Photographic prints--Hand-colored--1890-1910'],
#    'id': '93500178',
#    'link': 'https://www.loc.gov/pictures/item/93500178/',
#    'location': ['Japan--Nagoya-shi'],
#    'marc': 'https://www.loc.gov/pictures/item/93500178/marc/',
#    'medium': ['1 photographic print : hand-colored.'],
#    'medium_brief': '1 photographic print :',
#    'mediums': ['1 photographic print : hand-colored.'],
#    'modified': '2016-04-21T02:10:05Z',
#    'notes': ['No. 100 B.'],
#    'number_former_id': ['https://www.loc.gov/item/93500178',
#     'https://www.loc.gov/item/11612715'],
#    'other_control_numbers': ['11612715'],
#    'place': [{'latitude': '',
#      'link': 'https://www.loc.gov/pictures/related/?fi=place&q=Japan--Nagoya-shi&co=cph',
#      'longitude': '',
#      'title': 'Japan--Nagoya-shi'}],
#    'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA',
#    'reproduction_number': 'LC-USZC4-2295 (color film copy transparency)',
#    'resource_links': ['//hdl.loc.gov/loc.pnp/cph.3g02295'],
#    'service_low': 'https://tile.loc.gov/storage-services/service/pnp/cph/3g00000/3g02000/3g02200/3g02295_150px.jpg',
#    'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/cph/3g00000/3g02000/3g02200/3g02295r.jpg',
#    'sort_date': '1890',
#    'source_created': '1993-01-07T00:00:00Z',
#    'source_modified': '2002-11-09T14:35:52Z',
#    'subject_headings': ['Nagoyajō (Nagoya-shi, Japan)--1890-1910.',
#     'Castles & palaces--Japan--Nagoya-shi--1890-1910.',
#     'Japan--Nagoya-Shi'],
#    'subjects': ['Nagoyajō (Nagoya-shi, Japan)--1890-1910',
#     'Castles & palaces--Japan--Nagoya-shi--1890-1910'],
#    'summary': 'Castle at Nagoya, Japan.',
#    'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/cph/3g00000/3g02000/3g02200/3g02295_150px.jpg',
#    'title': 'Nagoya castle'},
#   'language': ['english'],
#   'location': ['nagoya', 'japan'],
#   'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#   'number': ['93500178',
#    'http://www.loc.gov/item/93500178',
#    '2002-11-09t14:35:52',
#    'http://www.loc.gov/item/11612715'],
#   'number_former_id': ['http://www.loc.gov/item/11612715',
#    'http://www.loc.gov/item/93500178'],
#   'number_lccn': ['93500178'],
#   'number_source_modified': ['2002-11-09t14:35:52'],
#   'online_format': ['image'],
#   'original_format': ['photo, print, drawing'],
#   'partof': ['prints & photographs online catalog (library of congress)',
#    'lot 6373',
#    'catalog',
#    'miscellaneous items in high demand',
#    'prints and photographs division'],
#   'related': {'group_record': 'https://www.loc.gov/pictures/search/?q=LOT 6373&fi=number&op=PHRASE&va=exact&co=coll&sg=true',
#    'neighbors': 'https://www.loc.gov/pictures/related/?&co=cph&pk=93500178&st=gallery&sb=call_number#focus'},
#   'reproductions': '<p>If an image is displaying, you can download it yourself. (Some images \ndisplay only as thumbnails outside the Library of Congress because of rights \nconsiderations, but you have access to larger size images on site.)\n</p>\n\n<p>  \nAlternatively, you can purchase copies of various types through Library \nof Congress Duplication Services</a>.\n</p>\n\n<p> \n<ol>\n<p>\n<li><strong>If a digital image is displaying:</strong> The qualities of the digital image \npartially depend on whether it was made from the original or an \nintermediate such as a copy negative or transparency. If the Reproduction \nNumber field above includes a reproduction number that starts with \nLC-DIG..., then there is a digital image that was made directly \nfrom the original and is of sufficient resolution for most publication\n purposes.\n</li> \n</p>\n\n<li><strong>If there is information listed in the Reproduction Number field above:</strong> \nYou can use the reproduction number to purchase a copy from Duplication \nServices.  It will be made from the source listed in the parentheses after\n the number.  \n<p> \nIf only black-and-white (&quot;b&w&quot;) sources are listed and you \n desire a copy showing color or tint (assuming the original has any), \n you can generally purchase a quality copy of the original in color by \n citing the Call Number listed above and including the catalog record \n (&quot;About This Item&quot;) with your request.\n </p>\n</li>\n\n<li><strong>If there is no information listed in the Reproduction Number field \nabove:</strong> You can generally purchase a quality copy through \nDuplication Services. Cite the Call Number listed above and include the catalog record (&quot;About This Item&quot;) with \n your request.\n</li>\n</ol>\n</p>\n\n<p> \nPrice lists, contact information, and order forms are available on the\n <a href="//www.loc.gov/duplicationservices/">Duplication Services Web site</a>.  \n</p>\n\n\n\n',
#   'resources': [{'caption': 'color film copy transparency',
#     'files': 1,
#     'image': 'https://tile.loc.gov/storage-services/service/pnp/cph/3g00000/3g02000/3g02200/3g02295_150px.jpg',
#     'url': 'https://www.loc.gov/resource/cph.3g02295/'}],
#   'shelf_id': 'LOT 6373, no. 62  <item> [P&P]',
#   'site': ['pictures', 'catalog'],
#   'subject': ['nagoya-shi',
#    'japan',
#    'photographic prints',
#    'castles & palaces',
#    'nagoyajō (nagoya-shi, japan)',
#    'hand-colored'],
#   'timestamp': '2022-05-02T12:01:29.774Z',
#   'title': 'Nagoya castle',
#   'unrestricted': True,
#   'url': 'https://www.loc.gov/item/93500178/'},
#  {'access_restricted': False,
#   'aka': ['http://www.loc.gov/pictures/collection/pgz/item/2001705953/',
#    'http://www.loc.gov/item/2001705953/',
#    'http://www.loc.gov/pictures/item/2001705953/',
#    'https://hdl.loc.gov/loc.pnp/ppmsc.07546',
#    'http://www.loc.gov/resource/ppmsc.07546/',
#    'http://lccn.loc.gov/2001705953'],
#   'campaigns': [],
#   'date': '1890-01-01',
#   'description': ['1 photomechanical print : photochrom, color.'],
#   'digitized': True,
#   'extract_timestamp': '2021-09-01T22:59:35.625Z',
#   'group': ['pgz',
#    'catalog-split-00',
#    'catalog',
#    'photochrom',
#    'main-catalog-split-00',
#    'main-catalog'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/2001705953/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/pnp/ppmsc/07500/07546_150px.jpg#h=112&w=150',
#    'https://tile.loc.gov/storage-services/service/pnp/ppmsc/07500/07546t.gif#h=112&w=150',
#    'https://tile.loc.gov/storage-services/service/pnp/ppmsc/07500/07546r.jpg#h=477&w=640',
#    'https://tile.loc.gov/storage-services/service/pnp/ppmsc/07500/07546v.jpg#h=763&w=1024'],
#   'index': 7,
#   'item': {'call_number': 'LOT 13407, no. 035 [item] [P&P]',
#    'control_number': '2001705953',
#    'created': '2016-04-20 08:33:22',
#    'created_published': '[between ca. 1890 and ca. 1900].',
#    'created_published_date': '[between ca. 1890 and ca. 1900].',
#    'date': '[between ca. 1890 and ca. 1900].',
#    'digital_id': ['ppmsc 07546 //hdl.loc.gov/loc.pnp/ppmsc.07546'],
# ...
#    'http://www.loc.gov/pictures/item/2023708415/',
#    'https://www.loc.gov/pictures/collection/ade/item/2023708415/',
#    'http://www.loc.gov/pictures/collection/ade/item/2023708415/',
#    'https://hdl.loc.gov/loc.pnp/ade.2a03093',
#    'https://hdl.loc.gov/loc.pnp/ade.2a03093',
#    'http://www.loc.gov/resource/ade.2a03093/',
#    'http://lccn.loc.gov/2023708415'],
#   'campaigns': [],
#   'contributor': ['jarvis, isabel f.'],
#   'date': '1968',
#   'dates': ['1968'],
#   'description': ['1 drawing : ink and watercolor on paper.'],
#   'digitized': True,
#   'extract_timestamp': '2023-12-09T13:29:31.516Z',
#   'group': ['ade',
#    'catalog-split-00',
#    'catalog',
#    'architecture-design-and-engineering-drawings',
#    'main-catalog-split-00'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/2023708415/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/pnp/ade/2a03000/2a03000/2a03093_150px.jpg#h=115&w=150'],
#   'index': 24,
#   'item': {'call_number': 'ADE 11 - Jarvis, no. 10 (A size) [P&P]',
#    'contributors': ['Jarvis, Isabel F., artist, copyright claimant'],
#    'control_number': '2023708415',
#    'created': '2023-12-05T06:17:25Z',
#    'created_published': 'c1968.',
#    'created_published_date': 'c1968.',
#    'creators': [{'link': 'https://www.loc.gov/pictures/related/?fi=name&q=Jarvis%2C%20Isabel%20F.&co=ade',
#      'role': 'artist',
#      'title': 'Jarvis, Isabel F.'},
#     {'link': 'https://www.loc.gov/pictures/related/?fi=name&q=Jarvis%2C%20Isabel%20F.&co=ade',
#      'role': 'copyright claimant',
#      'title': 'Jarvis, Isabel F.'}],
#    'date': 'c1968.',
#    'digital_id': ['ade 2a03093 https://hdl.loc.gov/loc.pnp/ade.2a03093'],
#    'format': ['still image'],
#    'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Drawings--1960-1970.&co=ade',
#      'title': 'Drawings--1960-1970.'},
#     {'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Illustrations--1960-1970.&co=ade',
#      'title': 'Illustrations--1960-1970.'}],
#    'genre': ['Illustrations--1960-1970', 'Drawings--1960-1970'],
#    'id': '2023708415',
#    'language': ['eng'],
#    'link': 'https://www.loc.gov/pictures/item/2023708415/',
#    'marc': 'https://www.loc.gov/pictures/item/2023708415/marc/',
#    'medium': ['1 drawing : ink and watercolor on paper.'],
#    'medium_brief': '1 drawing :',
#    'mediums': ['1 drawing : ink and watercolor on paper.'],
#    'modified': '2023-12-05T06:17:25Z',
#    'notes': ['Title devised by Library staff.',
#     'Built "1732, 1765, 1845" front.',
#     '"Courthouses I have seen, no. 63."',
#     'mi/860215.',
#     'This catalog record contains preliminary or unverified data from a project done in BRS software, ca. 1985.'],
#    'number_former_id': ['https://www.loc.gov/item/2023708415',
#     'https://www.loc.gov/item/ade1997000568/PP'],
#    'other_control_numbers': ['23345828', 'ade1997000568/PP'],
#    'place': [{'latitude': '',
#      'link': 'https://www.loc.gov/pictures/related/?fi=place&q=Delaware--New%20Castle&co=ade',
#      'longitude': '',
#      'title': 'Delaware--New Castle'}],
#    'raw_collections': ['ade', 'pp'],
#    'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA https://hdl.loc.gov/loc.pnp/pp.print',
#    'resource_links': ['https://hdl.loc.gov/loc.pnp/ade.2a03093'],
#    'rights_advisory': 'Publication may be restricted. For information see "Architecture, Design, and Engineering (ADE) Drawings," https://hdl.loc.gov/loc.pnp/res.103.ade',
#    'rights_information': 'Publication may be restricted. For information see "Architecture, Design, and Engineering (ADE) Drawings," https://hdl.loc.gov/loc.pnp/res.103.ade',
#    'service_low': 'https://tile.loc.gov/storage-services/service/pnp/ade/2a03000/2a03000/2a03093_150px.jpg',
#    'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/ade/2a03000/2a03000/2a03093r.jpg',
#    'sort_date': '1968',
#    'source_created': '2023-09-15T00:00:00Z',
#    'source_modified': '2023-12-01T12:08:15Z',
#    'stmt_of_responsibility': 'Isabel F. Jarvis.',
#    'subject_headings': ['Courthouses.',
#     'Towers.',
#     'Weather vanes.',
#     'United States--Delaware--New Castle.',
#     'Delaware--New Castle'],
#    'subjects': ['Courthouses',
#     'Towers',
#     'Weather vanes',
#     'United States--Delaware--New Castle'],
#    'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/ade/2a03000/2a03000/2a03093_150px.jpg',
#    'title': '[New Castle County Court House, New Castle, Del.]'},
#   'language': ['english'],
#   'location': ['delaware', 'new castle', 'united states'],
#   'location_city': ['new castle'],
#   'location_country': ['united states'],
#   'location_state': ['delaware'],
#   'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#   'number': ['http://www.loc.gov/item/2023708415',
#    'sheet',
#    'http://www.loc.gov/item/23345828',
#    'http://www.loc.gov/item/ade1997000568/pp',
#    '2023-12-01t12:08:15',
#    '2023708415'],
#   'number_carrier_type': ['sheet'],
#   'number_former_id': ['http://www.loc.gov/item/23345828',
#    'http://www.loc.gov/item/ade1997000568/pp',
#    'http://www.loc.gov/item/2023708415'],
#   'number_lccn': ['2023708415'],
#   'number_source_modified': ['2023-12-01t12:08:15'],
#   'online_format': ['image'],
#   'original_format': ['photo, print, drawing'],
#   'partof': ['architecture, design & engineering drawings',
#    'catalog',
#    'prints and photographs division'],
#   'related': {'neighbors': 'https://www.loc.gov/pictures/related/?&co=ade&pk=2023708415&st=gallery&sb=call_number#focus'},
#   'reproductions': '<p>\n<b>Step 1:</b> Look in the <strong>Medium</strong> field above to \ndetermine whether the record is describing one drawing or more than one.\n The Architectural, Design and Engineering Drawings include records \n for groups of drawings and single drawings. \n</p>\n\n<p><strong>Step 2:</strong> Determine which category below fits the \ncircumstances.\n</p>\n\n<h3>SINGLE DRAWINGS</h3>\n\n<p>If an image is displaying, you can download it yourself (some images \ndisplay only as thumbnails outside the Library of Congress, but you have\n access to larger size images on site). \n</p>\n\n<p>Alternatively, you can purchase copies of various types through \nLibrary of Congress Duplication Services.\n</p>\n\n<ol>\n<p>\n<li><strong>If a digital image is displaying:</strong> The qualities \nof the digital image partially depend on whether it was made from the \noriginal or an intermediate such as a copy negative or transparency. \nIf the Reproduction Number field above includes a reproduction number \nthat starts with LC-DIG..., then there is a digital image that was \nmade directly from the original and is of sufficient resolution for \nmost publication purposes.</li> \n</p>\n\n<p>\n<li><strong>If there is information listed in the Reproduction Number \nfield above:</strong> You can use the reproduction number to purchase \na copy from Duplication Services. It will be made from the source \nlisted in the parentheses after the number. If only black-and-white\n (&quot;b&amp;w&quot;) sources are listed and you desire a copy showing color or tint (assuming the original has any), you will need to order photography of the original in color. Order photography of the original by citing the Call Number listed above and including the catalog record ("About This Item") with your request.</li> \n</p>\n\n<p>\n<li><strong>If there is no information listed in the Reproduction Number\n field above:</strong> The original will have to be photographed by \n Duplication Services. Order photography of the original by citing the \n Call Number listed above and including the catalog record (&quot;About This \n Item&quot;) with your request.</li>\n</p>\n</ol>\n\n<p>\nPrice lists, contact information, and order forms are available on the \n<a href="https://www.loc.gov/duplicationservices/">Duplication Services Web site</a>.\n</p>\n\t\n<h3>GROUPS OF DRAWINGS</h3>\n\n<p>A selection must be made from the group:</p>\n\n<ul>\n<p>\n<li>Try the &quot;<em>Check for online items from this \ngroup</em>&quot; link to see if any of the individual images \nin the group have been cataloged online/digitized. If so, see \ninformation above for single drawings.</li>\n</p>\n\n<p>\t\n<li>If the items in the group are not online, generally you will need\n to visit the Prints &amp; Photographs Reading Room (see information \n on <a href="https://www.loc.gov/rr/print/info/096a_ade.html">service\n      of architectural drawings</a>). </li>\n</p>\n\n<p>\t\n<li>It is not possible to photocopy (&quot;quick copy&quot;) original \ndrawings.</li>\n</p>\t\n</ul> ',
#   'resources': [{'caption': 'digital file from intermediary roll film',
#     'files': 1,
#     'image': 'https://tile.loc.gov/storage-services/service/pnp/ade/2a03000/2a03000/2a03093_150px.jpg',
#     'url': 'https://www.loc.gov/resource/ade.2a03093/'}],
#   'shelf_id': 'ADE 11 - Jarvis, no. 10 (A size) [P&P]',
#   'site': ['pictures', 'catalog'],
#   'subject': ['united states',
#    'towers',
#    'drawings',
#    'illustrations',
#    'weather vanes',
#    'courthouses',
#    'delaware',
#    'new castle'],
#   'timestamp': '2023-12-09T13:31:55.673Z',
#   'title': '[New Castle County Court House, New Castle, Del.]',
#   'type': ['still image'],
#   'unrestricted': True,
#   'url': 'https://www.loc.gov/item/2023708415/'},
#  {'access_restricted': True,
#   'aka': ['https://www.loc.gov/pictures/item/95507566/',
#    'http://www.loc.gov/item/95507566/',
#    'http://www.loc.gov/pictures/item/95507566/',
#    'https://www.loc.gov/pictures/collection/cph/item/95507566/',
#    'http://www.loc.gov/pictures/collection/cph/item/95507566/',
#    'http://www.loc.gov/resource/cph.3c13133/',
#    'https://hdl.loc.gov/loc.pnp/cph.3c13133',
#    'http://lccn.loc.gov/95507566'],
#   'campaigns': [],
#   'date': '1900-01-01',
#   'dates': ['1900'],
#   'description': ['1 photomechanical print : halftone.'],
#   'digitized': True,
#   'extract_timestamp': '2021-08-24T22:05:32.860Z',
#   'group': ['cph',
#    'catalog-split-11',
#    'catalog',
#    'miscellaneous-items-high-demand',
#    'main-catalog-split-11',
#    'main-catalog'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/95507566/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/pnp/cph/3c10000/3c13000/3c13100/3c13133_150px.jpg#h=118&w=150'],
#   'index': 25,
#   'item': {'call_number': 'FOREIGN GEOG FILE - England--Hastings  <item> [P&P]',
#    'control_number': '95507566',
#    'created': '2016-04-20T14:14:10Z',
#    'created_published': '[between 1900 and 1930]',
#    'created_published_date': '[between 1900 and 1930]',
#    'date': '[between 1900 and 1930]',
#    'digital_id': ['cph 3c13133 //hdl.loc.gov/loc.pnp/cph.3c13133'],
#    'format': ['still image'],
#    'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Halftone%20photomechanical%20prints--1900-1930.&co=cph',
#      'title': 'Halftone photomechanical prints--1900-1930.'}],
#    'genre': ['Halftone photomechanical prints--1900-1930'],
#    'id': '95507566',
#    'link': 'https://www.loc.gov/pictures/item/95507566/',
#    'location': ['England--Hastings'],
#    'marc': 'https://www.loc.gov/pictures/item/95507566/marc/',
#    'medium': ['1 photomechanical print : halftone.'],
#    'medium_brief': '1 photomechanical print :',
#    'mediums': ['1 photomechanical print : halftone.'],
#    'modified': '2016-04-20T14:14:10Z',
#    'notes': ['From: Geography of the British Isles, castles, nos. 17 to 28.'],
#    'number_former_id': ['https://www.loc.gov/item/95507566',
#     'https://www.loc.gov/item/11649497'],
#    'other_control_numbers': ['11649497'],
#    'place': [{'latitude': '',
#      'link': 'https://www.loc.gov/pictures/related/?fi=place&q=England--Hastings&co=cph',
#      'longitude': '',
#      'title': 'England--Hastings'}],
#    'reproduction_number': 'LC-USZ62-113133 (b&w film copy neg.)',
#    'resource_links': ['//hdl.loc.gov/loc.pnp/cph.3c13133'],
#    'service_low': 'https://tile.loc.gov/storage-services/service/pnp/cph/3c10000/3c13000/3c13100/3c13133_150px.jpg',
#    'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/cph/3c10000/3c13000/3c13100/3c13133r.jpg',
#    'sort_date': '1900',
#    'source_created': '1995-05-22T00:00:00Z',
#    'source_modified': '2002-11-09T20:21:16Z',
#    'stmt_of_responsibility': 'photo by the London Stereoscopic Co.',
#    'subject_headings': ['Castles & palaces--England--Hastings--1900-1930.',
#     'Ruins--England--Hastings--1900-1930.',
#     'England--Hastings'],
#    'subjects': ['Castles & palaces--England--Hastings--1900-1930',
#     'Ruins--England--Hastings--1900-1930'],
#    'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/cph/3c10000/3c13000/3c13100/3c13133_150px.jpg',
#    'title': 'Hastings Castle'},
#   'language': ['english'],
#   'location': ['hastings', 'england'],
#   'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#   'number': ['95507566',
#    '2002-11-09t20:21:16',
#    'http://www.loc.gov/item/11649497',
#    'http://www.loc.gov/item/95507566'],
#   'number_former_id': ['http://www.loc.gov/item/11649497',
#    'http://www.loc.gov/item/95507566'],
#   'number_lccn': ['95507566'],
#   'number_source_modified': ['2002-11-09t20:21:16'],
#   'online_format': ['image'],
#   'original_format': ['photo, print, drawing'],
#   'partof': ['prints & photographs online catalog (library of congress)',
#    'miscellaneous items in high demand',
#    'catalog',
#    'prints and photographs division'],
#   'related': {'neighbors': 'https://www.loc.gov/pictures/related/?&co=cph&pk=95507566&st=gallery&sb=call_number#focus'},
#   'reproductions': '<p>If an image is displaying, you can download it yourself. (Some images \ndisplay only as thumbnails outside the Library of Congress because of rights \nconsiderations, but you have access to larger size images on site.)\n</p>\n\n<p>  \nAlternatively, you can purchase copies of various types through Library \nof Congress Duplication Services</a>.\n</p>\n\n<p> \n<ol>\n<p>\n<li><strong>If a digital image is displaying:</strong> The qualities of the digital image \npartially depend on whether it was made from the original or an \nintermediate such as a copy negative or transparency. If the Reproduction \nNumber field above includes a reproduction number that starts with \nLC-DIG..., then there is a digital image that was made directly \nfrom the original and is of sufficient resolution for most publication\n purposes.\n</li> \n</p>\n\n<li><strong>If there is information listed in the Reproduction Number field above:</strong> \nYou can use the reproduction number to purchase a copy from Duplication \nServices.  It will be made from the source listed in the parentheses after\n the number.  \n<p> \nIf only black-and-white (&quot;b&w&quot;) sources are listed and you \n desire a copy showing color or tint (assuming the original has any), \n you can generally purchase a quality copy of the original in color by \n citing the Call Number listed above and including the catalog record \n (&quot;About This Item&quot;) with your request.\n </p>\n</li>\n\n<li><strong>If there is no information listed in the Reproduction Number field \nabove:</strong> You can generally purchase a quality copy through \nDuplication Services. Cite the Call Number listed above and include the catalog record (&quot;About This Item&quot;) with \n your request.\n</li>\n</ol>\n</p>\n\n<p> \nPrice lists, contact information, and order forms are available on the\n <a href="//www.loc.gov/duplicationservices/">Duplication Services Web site</a>.  \n</p>\n\n\n\n',
#   'resources': [{'caption': 'b&w film copy neg.',
#     'files': 1,
#     'image': 'https://tile.loc.gov/storage-services/service/pnp/cph/3c10000/3c13000/3c13100/3c13133_150px.jpg',
#     'url': 'https://www.loc.gov/resource/cph.3c13133/'}],
#   'shelf_id': 'FOREIGN GEOG FILE - England--Hastings  <item> [P&P]',
#   'site': ['pictures', 'catalog'],
#   'subject': ['hastings',
#    'england',
#    'castles & palaces',
#    'ruins',
#    'halftone photomechanical prints'],
#   'timestamp': '2022-05-02T12:29:05.371Z',
#   'title': 'Hastings Castle',
#   'unrestricted': True,
#   'url': 'https://www.loc.gov/item/95507566/'}]
