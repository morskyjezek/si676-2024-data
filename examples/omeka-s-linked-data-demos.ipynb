# %% [markdown]
# # Linked Data
#
# Testing with Omeka S API
#
# ## Setup

# %%
import requests
import rdflib
from rdflib import Graph, plugin, URIRef, Literal
from rdflib.serializer import Serializer
from rdflib.plugin import register, Parser
from rdflib import Namespace, RDF, BNode, plugin, Variable, FOAF, SDO

# %%
# create sample data to add to the graph
newData = {
    'J.D. Salinger' : { 
        'https://schema.org/deathDate' : 2010,
        'https://schema.org/deathPlace': 'https://en.wikipedia.org/wiki/New_York_City'
        },
    'Herman Melvill' : { 
        'https://schema.org/deathDate' : 1862,
        'https://schema.org/deathPlace' : 'https://en.wikipedia.org/wiki/New_York_City'
        }
}

# %% [markdown]
# ## Searching in Omeka S
#
# Search for all the items in the specified set

# %%
url = 'http://jajohnst.si676.si.umich.edu/omeka-s/api'
action = '/items'
parameters = {
    'fulltext_search':'',
#    property%5B0%5D%5Bjoiner%5D=and
#    property%5B0%5D%5Bproperty%5D=
#    property%5B0%5D%5Btype%5D=eq
#    property%5B0%5D%5Btext%5D=
#    resource_class_id%5B%5D=
#    resource_template_id%5B%5D=
    'item_set_id':989,
#    site_id=
#    owner_id=
    'submit':'Search'
}

# %%
r = requests.get(url + action)

print(r.url)
# Out:
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items

# %%
r.json()
# Out:
# [{'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367',
#   '@type': 'o:Item',
#   'o:id': 367,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Carnegie Library, Cordele, Georgia',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/44edc7c60885f9d17744495b09836a22673ca3f1.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/44edc7c60885f9d17744495b09836a22673ca3f1.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/44edc7c60885f9d17744495b09836a22673ca3f1.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:13+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:13+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/382',
#    'o:id': 382},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/382',
#     'o:id': 382}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Carnegie Library, Cordele, Georgia',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '91787443',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/91787443/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1916-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'No known restrictions on publication.',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368',
#   '@type': 'o:Item',
#   'o:id': 368,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Carnegie Library, Sheldon, Iowa',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/3269a2ffcb91d1660eecf86247b15a76f7fa0dde.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/3269a2ffcb91d1660eecf86247b15a76f7fa0dde.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/3269a2ffcb91d1660eecf86247b15a76f7fa0dde.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:13+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:13+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/383',
#    'o:id': 383},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/383',
#     'o:id': 383}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Carnegie Library, Sheldon, Iowa',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '97511671',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/97511671/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1909-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'Undetermined',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369',
#   '@type': 'o:Item',
#   'o:id': 369,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Curb service 10,000 current books - convenient, free, time saving : Chicago Public Library, Randolph St. corridor.',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/1a75227c0aeb082af58f40dc55d5c9940a484810.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/1a75227c0aeb082af58f40dc55d5c9940a484810.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/1a75227c0aeb082af58f40dc55d5c9940a484810.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:13+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:13+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/384',
#    'o:id': 384},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/384',
#     'o:id': 384}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Curb service 10,000 current books - convenient, free, time saving : Chicago Public Library, Randolph St. corridor.',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '98508385',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/98508385/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1936-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'No known restrictions on publication.',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370',
#   '@type': 'o:Item',
#   'o:id': 370,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'For greater knowledge on more subjects use your library more often',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/fc27f23352f9c82dd51a322c3a228b7a3c035c93.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/fc27f23352f9c82dd51a322c3a228b7a3c035c93.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/fc27f23352f9c82dd51a322c3a228b7a3c035c93.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:13+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:13+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/385',
#    'o:id': 385},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/385',
#     'o:id': 385}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'For greater knowledge on more subjects use your library more often',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '98508155',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/98508155/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1936-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'No known restrictions on publication.',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371',
#   '@type': 'o:Item',
#   'o:id': 371,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': '[Cossitt Library, Memphis, Tenn.]',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/e77fb3c033a785b61a5fc6aa5a0e20d8a96ae969.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/e77fb3c033a785b61a5fc6aa5a0e20d8a96ae969.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/e77fb3c033a785b61a5fc6aa5a0e20d8a96ae969.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:14+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:14+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/386',
#    'o:id': 386},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/386',
#     'o:id': 386}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': '[Cossitt Library, Memphis, Tenn.]',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '2016809661',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/2016809661/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1906-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'No known restrictions on publication.',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372',
#   '@type': 'o:Item',
#   'o:id': 372,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Little Rock Public Library, Little Rock, Ark.',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/0386789ee6e58ba7f70553e37071cb47e4abc2c7.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/0386789ee6e58ba7f70553e37071cb47e4abc2c7.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/0386789ee6e58ba7f70553e37071cb47e4abc2c7.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:14+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:14+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/387',
#    'o:id': 387},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/387',
#     'o:id': 387}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Little Rock Public Library, Little Rock, Ark.',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '2016815290',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/2016815290/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1905-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'No known restrictions on publication.',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373',
#   '@type': 'o:Item',
#   'o:id': 373,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Newspaper reading room of public library. Omaha, Nebraska',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/b770fceca21e76f0bf117ae0f88b5830957ca4c3.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/b770fceca21e76f0bf117ae0f88b5830957ca4c3.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/b770fceca21e76f0bf117ae0f88b5830957ca4c3.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:14+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:14+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/388',
#    'o:id': 388},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/388',
#     'o:id': 388}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Newspaper reading room of public library. Omaha, Nebraska',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '2017762724',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/2017762724/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1938-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374',
#   '@type': 'o:Item',
#   'o:id': 374,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Public library in the southwestern section of Mississippi, in the piney woods',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/7e42d73ce391940b8268368b040f787d424f3c69.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/7e42d73ce391940b8268368b040f787d424f3c69.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/7e42d73ce391940b8268368b040f787d424f3c69.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:15+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:15+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/389',
#    'o:id': 389},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/389',
#     'o:id': 389}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Public library in the southwestern section of Mississippi, in the piney woods',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '2017770391',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/2017770391/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1937-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375',
#   '@type': 'o:Item',
#   'o:id': 375,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Library tent at the FSA (Farm Security Administration) mobile camp for migratory farm workers. Odell, Oregon. The girls working in the library receive credit in the Junior Campers League for work in the library',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/ffdb26e050cc21537b0814d059f30551fcc47f22.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/ffdb26e050cc21537b0814d059f30551fcc47f22.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/ffdb26e050cc21537b0814d059f30551fcc47f22.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:15+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:15+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/390',
#    'o:id': 390},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/390',
#     'o:id': 390}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Library tent at the FSA (Farm Security Administration) mobile camp for migratory farm workers. Odell, Oregon. The girls working in the library receive credit in the Junior Campers League for work in the library',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '2017815837',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/2017815837/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1941-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376',
#   '@type': 'o:Item',
#   'o:id': 376,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/7bf9000db7908c6c3e947f25fd0462a263f591c4.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/7bf9000db7908c6c3e947f25fd0462a263f591c4.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/7bf9000db7908c6c3e947f25fd0462a263f591c4.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:15+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:15+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/391',
#    'o:id': 391},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/391',
#     'o:id': 391}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '2017843202',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/2017843202/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1943-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377',
#   '@type': 'o:Item',
#   'o:id': 377,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Libraries, Washington D.C.',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/5c76156ac4dbbcf0354e1fc9d0ea53e092ed8dcc.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/5c76156ac4dbbcf0354e1fc9d0ea53e092ed8dcc.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/5c76156ac4dbbcf0354e1fc9d0ea53e092ed8dcc.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:16+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:16+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/392',
#    'o:id': 392},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/392',
#     'o:id': 392}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Libraries, Washington D.C.',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '87694100',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/87694100/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1926-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'map': 'https://www.loc.gov/search/?fa=original_format:map&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'Undetermined',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378',
#   '@type': 'o:Item',
#   'o:id': 378,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Carnegie Library, Cordele, Georgia',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/c3f2b002a8998633f6db28201cd219d6ed091483.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/c3f2b002a8998633f6db28201cd219d6ed091483.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/c3f2b002a8998633f6db28201cd219d6ed091483.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:16+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:16+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/393',
#    'o:id': 393},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/393',
#     'o:id': 393}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Carnegie Library, Cordele, Georgia',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '91787443',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/91787443/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1916-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'No known restrictions on publication.',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379',
#   '@type': 'o:Item',
#   'o:id': 379,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Carnegie Library, Sheldon, Iowa',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/9c5d697d9a98eb298ff837e8117425138533a0c6.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/9c5d697d9a98eb298ff837e8117425138533a0c6.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/9c5d697d9a98eb298ff837e8117425138533a0c6.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:16+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:16+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/394',
#    'o:id': 394},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/394',
#     'o:id': 394}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Carnegie Library, Sheldon, Iowa',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '97511671',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/97511671/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1909-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'Undetermined',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380',
#   '@type': 'o:Item',
#   'o:id': 380,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Curb service 10,000 current books - convenient, free, time saving : Chicago Public Library, Randolph St. corridor.',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/e9eb38e39f62fa76ac4bb799135f8efdb3b27b94.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/e9eb38e39f62fa76ac4bb799135f8efdb3b27b94.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/e9eb38e39f62fa76ac4bb799135f8efdb3b27b94.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:17+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:17+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/395',
#    'o:id': 395},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/395',
#     'o:id': 395}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Curb service 10,000 current books - convenient, free, time saving : Chicago Public Library, Randolph St. corridor.',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '98508385',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/98508385/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1936-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'No known restrictions on publication.',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381',
#   '@type': 'o:Item',
#   'o:id': 381,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'For greater knowledge on more subjects use your library more often',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/329bc61557e81537259b17bcd2576858666ecfc6.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/329bc61557e81537259b17bcd2576858666ecfc6.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/329bc61557e81537259b17bcd2576858666ecfc6.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:17+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:17+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/396',
#    'o:id': 396},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/396',
#     'o:id': 396}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'For greater knowledge on more subjects use your library more often',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '98508155',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/98508155/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1936-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'No known restrictions on publication.',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397',
#   '@type': 'o:Item',
#   'o:id': 397,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': '[Cossitt Library, Memphis, Tenn.]',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/44608e5fa77ddfad01004f2913ecdefec4c3c0e7.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/44608e5fa77ddfad01004f2913ecdefec4c3c0e7.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/44608e5fa77ddfad01004f2913ecdefec4c3c0e7.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:17+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:17+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/404',
#    'o:id': 404},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/404',
#     'o:id': 404}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': '[Cossitt Library, Memphis, Tenn.]',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '2016809661',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/2016809661/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1906-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'No known restrictions on publication.',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398',
#   '@type': 'o:Item',
#   'o:id': 398,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Little Rock Public Library, Little Rock, Ark.',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/0d70fd1e23bd9f662482caa50f28db568c1a455e.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/0d70fd1e23bd9f662482caa50f28db568c1a455e.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/0d70fd1e23bd9f662482caa50f28db568c1a455e.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:17+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:17+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/405',
#    'o:id': 405},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/405',
#     'o:id': 405}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Little Rock Public Library, Little Rock, Ark.',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '2016815290',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/2016815290/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1905-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'No known restrictions on publication.',
#     '@language': 'en-us'}]},
# ...
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Library tent at the FSA (Farm Security Administration) mobile camp for migratory farm workers. Odell, Oregon. The girls working in the library receive credit in the Junior Campers League for work in the library',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '2017815837',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/2017815837/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1941-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402',
#   '@type': 'o:Item',
#   'o:id': 402,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/d289f6c5fa6757dd20acdff1723b3d9835dfeaca.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/d289f6c5fa6757dd20acdff1723b3d9835dfeaca.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/d289f6c5fa6757dd20acdff1723b3d9835dfeaca.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:19+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:19+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/409',
#    'o:id': 409},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/409',
#     'o:id': 409}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '2017843202',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/2017843202/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1943-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403',
#   '@type': 'o:Item',
#   'o:id': 403,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Libraries, Washington D.C.',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/16e387f4b00834945db39829f83e09c62f068f44.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/16e387f4b00834945db39829f83e09c62f068f44.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/16e387f4b00834945db39829f83e09c62f068f44.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:19+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:19+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/410',
#    'o:id': 410},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/410',
#     'o:id': 410}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Libraries, Washington D.C.',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '87694100',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/87694100/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '1926-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'map': 'https://www.loc.gov/search/?fa=original_format:map&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'Undetermined',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411',
#   '@type': 'o:Item',
#   'o:id': 411,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'George Peabody Library, formerly the Library of the Peabody Institute of the City of Baltimore, is part of the Johns Hopkins Sheridan Libraries. Baltimore, Maryland',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/c9ae115fd60b9602a3c5cddc48e431974223da63.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/c9ae115fd60b9602a3c5cddc48e431974223da63.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/c9ae115fd60b9602a3c5cddc48e431974223da63.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:19+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:19+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/417',
#    'o:id': 417},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/417',
#     'o:id': 417}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'George Peabody Library, formerly the Library of the Peabody Institute of the City of Baltimore, is part of the Johns Hopkins Sheridan Libraries. Baltimore, Maryland',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '2013646466',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/2013646466/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '2012-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'No known restrictions on publication.',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412',
#   '@type': 'o:Item',
#   'o:id': 412,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Handley Library, Winchester, Virginia',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/fb8e0635d77d2da8558d5a0fbb0f1aa50e429391.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/fb8e0635d77d2da8558d5a0fbb0f1aa50e429391.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/fb8e0635d77d2da8558d5a0fbb0f1aa50e429391.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:20+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:20+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/418',
#    'o:id': 418},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/418',
#     'o:id': 418}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Handley Library, Winchester, Virginia',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '2012630178',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/2012630178/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '2011-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'No known restrictions on publication.',
#     '@language': 'en-us'}]},
#  {'@context': 'http://jajohnst.si676.si.umich.edu/omeka-s/api-context',
#   '@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413',
#   '@type': 'o:Item',
#   'o:id': 413,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1',
#    'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Public library building in the town of Antonito in Conejos County, Colorado, near the New Mexico border',
#   'thumbnail_display_urls': {'large': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/large/b79c9cc8e2a0559806ceb13f97cd0b86ddd3a5fb.jpg',
#    'medium': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/medium/b79c9cc8e2a0559806ceb13f97cd0b86ddd3a5fb.jpg',
#    'square': 'http://jajohnst.si676.si.umich.edu/omeka-s/files/square/b79c9cc8e2a0559806ceb13f97cd0b86ddd3a5fb.jpg'},
#   'o:created': {'@value': '2024-11-13T20:24:20+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2024-11-13T20:24:20+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:primary_media': {'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/419',
#    'o:id': 419},
#   'o:media': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/media/419',
#     'o:id': 419}],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1',
#     'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Public library building in the town of Antonito in Conejos County, Colorado, near the New Mexico border',
#     '@language': 'en-us'}],
#   'dcterms:identifier': [{'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': '2017686535',
#     '@language': 'en-us'},
#    {'type': 'literal',
#     'property_id': 10,
#     'property_label': 'Identifier',
#     'is_public': True,
#     '@value': 'https://www.loc.gov/item/2017686535/',
#     '@language': 'en-us'}],
#   'dcterms:date': [{'type': 'literal',
#     'property_id': 7,
#     'property_label': 'Date',
#     'is_public': True,
#     '@value': '2015-01-01',
#     '@language': 'en-us'}],
#   'dcterms:isFormatOf': [{'type': 'literal',
#     'property_id': 37,
#     'property_label': 'Is Format Of',
#     'is_public': True,
#     '@value': "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}",
#     '@language': 'en-us'}],
#   'dcterms:type': [{'type': 'literal',
#     'property_id': 8,
#     'property_label': 'Type',
#     'is_public': True,
#     '@value': 'Image',
#     '@language': 'en-us'}],
#   'dcterms:rights': [{'type': 'literal',
#     'property_id': 15,
#     'property_label': 'Rights',
#     'is_public': True,
#     '@value': 'No known restrictions on publication.',
#     '@language': 'en-us'}]}]

# %% [markdown]
# ## Parse data with the RDFLib module
#
# Using the `rdflib` module capabilities, parse this data.
#
# First, create an RDF graph from it:

# %%
g = Graph().parse(data=r.text, format='json-ld')

# %% [markdown]
# Now, look through the graph. The graph is a series of "triples",
# which are subject-predicate-object tuples. These can be modified. example, after the initial look, you can remove all of those with the Omeka S namespace (`o`).
# Note that RDFLib may drop or delete any orphaned subjects or objects that may not be part of a triple.

# %%
for s, p, o in g:
    print(f'{s} -> {p} -> {o}.')
# Out:
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://purl.org/dc/terms/rights -> No known restrictions on publication..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/388 -> http://omeka.org/s/vocabs/o#id -> 388.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:17+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/404.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/385 -> http://omeka.org/s/vocabs/o#id -> 385.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:18+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/382 -> http://omeka.org/s/vocabs/o#id -> 382.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/386.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:20+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/391.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://omeka.org/s/vocabs/o#id -> 377.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://purl.org/dc/terms/identifier -> 2012630178.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:19+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/405.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2012630178/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://omeka.org/s/vocabs/o#id -> 401.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://purl.org/dc/terms/identifier -> 87694100.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://purl.org/dc/terms/identifier -> 91787443.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:16+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:19+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://purl.org/dc/terms/identifier -> 97511671.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/388.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/387 -> http://omeka.org/s/vocabs/o#id -> 387.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://purl.org/dc/terms/title -> Newspaper reading room of public library. Omaha, Nebraska.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://purl.org/dc/terms/identifier -> 98508155.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://omeka.org/s/vocabs/o#id -> 378.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://omeka.org/s/vocabs/o#id -> 372.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/409.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://purl.org/dc/terms/identifier -> 2017843202.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:15+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2017815837/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://omeka.org/s/vocabs/o#title -> Carnegie Library, Sheldon, Iowa.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://omeka.org/s/vocabs/o#title -> Library tent at the FSA (Farm Security Administration) mobile camp for migratory farm workers. Odell, Oregon. The girls working in the library receive credit in the Junior Campers League for work in the library.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:16+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://purl.org/dc/terms/date -> 1938-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:14+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/393 -> http://omeka.org/s/vocabs/o#id -> 393.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://purl.org/dc/terms/date -> 1905-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://omeka.org/s/vocabs/o#id -> 402.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://purl.org/dc/terms/rights -> Undetermined.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/392 -> http://omeka.org/s/vocabs/o#id -> 392.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://omeka.org/s/vocabs/o#title -> Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://purl.org/dc/terms/rights -> No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://purl.org/dc/terms/rights -> No known restrictions on publication..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://purl.org/dc/terms/title -> Carnegie Library, Sheldon, Iowa.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/395.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/394.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://purl.org/dc/terms/rights -> No known restrictions on publication..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/91787443/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1 -> http://omeka.org/s/vocabs/o#id -> 1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/97511671/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://purl.org/dc/terms/rights -> Undetermined.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://purl.org/dc/terms/date -> 1916-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:19+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://omeka.org/s/vocabs/o#id -> 399.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2016815290/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:17+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://omeka.org/s/vocabs/o#title -> Newspaper reading room of public library. Omaha, Nebraska.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://omeka.org/s/vocabs/o#title -> [Cossitt Library, Memphis, Tenn.].
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:16+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://purl.org/dc/terms/title -> Libraries, Washington D.C..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://purl.org/dc/terms/rights -> No known restrictions on publication..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/87694100/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://omeka.org/s/vocabs/o#title -> Handley Library, Winchester, Virginia.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:14+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/393.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/407.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://omeka.org/s/vocabs/o#title -> For greater knowledge on more subjects use your library more often.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1 -> http://omeka.org/s/vocabs/o#id -> 1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/417 -> http://omeka.org/s/vocabs/o#id -> 417.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://omeka.org/s/vocabs/o#title -> Carnegie Library, Cordele, Georgia.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://omeka.org/s/vocabs/o#id -> 369.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/417.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/389 -> http://omeka.org/s/vocabs/o#id -> 389.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/409 -> http://omeka.org/s/vocabs/o#id -> 409.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/382.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://purl.org/dc/terms/date -> 1936-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://purl.org/dc/terms/title -> Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://purl.org/dc/terms/date -> 1943-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://omeka.org/s/vocabs/o#title -> Curb service 10,000 current books - convenient, free, time saving : Chicago Public Library, Randolph St. corridor..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2017815837/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://purl.org/dc/terms/date -> 1936-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/418.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://purl.org/dc/terms/title -> Library tent at the FSA (Farm Security Administration) mobile camp for migratory farm workers. Odell, Oregon. The girls working in the library receive credit in the Junior Campers League for work in the library.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://purl.org/dc/terms/date -> 1926-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:20+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://purl.org/dc/terms/identifier -> 2016815290.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://omeka.org/s/vocabs/o#id -> 400.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:13+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/406.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://purl.org/dc/terms/identifier -> 2016809661.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://purl.org/dc/terms/identifier -> 2016815290.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://purl.org/dc/terms/rights -> No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/98508155/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/383.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2017770391/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://omeka.org/s/vocabs/o#id -> 367.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://purl.org/dc/terms/identifier -> 97511671.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:17+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/386.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:19+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://omeka.org/s/vocabs/o#title -> Libraries, Washington D.C..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://purl.org/dc/terms/identifier -> 2017762724.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://omeka.org/s/vocabs/o#id -> 413.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:18+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://purl.org/dc/terms/title -> Public library in the southwestern section of Mississippi, in the piney woods.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/384.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://omeka.org/s/vocabs/o#id -> 412.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:14+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:13+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://purl.org/dc/terms/rights -> No known restrictions on publication..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:16+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://purl.org/dc/terms/rights -> No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://purl.org/dc/terms/title -> Handley Library, Winchester, Virginia.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://omeka.org/s/vocabs/o#id -> 374.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:13+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://purl.org/dc/terms/identifier -> 2017770391.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:19+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://omeka.org/s/vocabs/o#title -> Curb service 10,000 current books - convenient, free, time saving : Chicago Public Library, Randolph St. corridor..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/410 -> http://omeka.org/s/vocabs/o#id -> 410.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://omeka.org/s/vocabs/o#title -> Public library building in the town of Antonito in Conejos County, Colorado, near the New Mexico border.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2017843202/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://purl.org/dc/terms/title -> Curb service 10,000 current books - convenient, free, time saving : Chicago Public Library, Randolph St. corridor..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://omeka.org/s/vocabs/o#id -> 380.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/387.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://purl.org/dc/terms/identifier -> 98508155.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2017686535/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2013646466/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:17+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:14+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://purl.org/dc/terms/date -> 1906-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://purl.org/dc/terms/identifier -> 98508385.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:18+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:13+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://purl.org/dc/terms/date -> 1943-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://purl.org/dc/terms/identifier -> 2017686535.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/394.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:15+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://purl.org/dc/terms/rights -> No known restrictions on publication..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/394 -> http://omeka.org/s/vocabs/o#id -> 394.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:13+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://purl.org/dc/terms/title -> For greater knowledge on more subjects use your library more often.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://purl.org/dc/terms/date -> 1906-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://purl.org/dc/terms/date -> 2012-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:19+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://purl.org/dc/terms/identifier -> 2017770391.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://omeka.org/s/vocabs/o#title -> Carnegie Library, Sheldon, Iowa.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/405 -> http://omeka.org/s/vocabs/o#id -> 405.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/396.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://purl.org/dc/terms/date -> 1936-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://purl.org/dc/terms/identifier -> 2013646466.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://omeka.org/s/vocabs/o#id -> 398.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/388.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://omeka.org/s/vocabs/o#id -> 379.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://purl.org/dc/terms/rights -> Undetermined.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/390.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/408.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://purl.org/dc/terms/title -> Carnegie Library, Cordele, Georgia.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/417.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://purl.org/dc/terms/identifier -> 2017762724.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:20+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://purl.org/dc/terms/isFormatOf -> {'map': 'https://www.loc.gov/search/?fa=original_format:map&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://purl.org/dc/terms/date -> 1937-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2017843202/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/391.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://purl.org/dc/terms/date -> 1938-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://omeka.org/s/vocabs/o#id -> 381.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://omeka.org/s/vocabs/o#title -> Public library in the southwestern section of Mississippi, in the piney woods.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:15+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/405.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/418.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:16+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/395.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://purl.org/dc/terms/rights -> No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/408 -> http://omeka.org/s/vocabs/o#id -> 408.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/383.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://purl.org/dc/terms/title -> Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://purl.org/dc/terms/date -> 2011-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:13+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://purl.org/dc/terms/rights -> No known restrictions on publication..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://omeka.org/s/vocabs/o#id -> 397.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2016809661/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://omeka.org/s/vocabs/o#id -> 370.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:14+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://purl.org/dc/terms/rights -> No known restrictions on publication..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://omeka.org/s/vocabs/o#title -> Libraries, Washington D.C..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://purl.org/dc/terms/date -> 1909-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/98508155/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://purl.org/dc/terms/title -> Carnegie Library, Sheldon, Iowa.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://purl.org/dc/terms/title -> Curb service 10,000 current books - convenient, free, time saving : Chicago Public Library, Randolph St. corridor..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/389.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://omeka.org/s/vocabs/o#title -> [Cossitt Library, Memphis, Tenn.].
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/91787443/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://purl.org/dc/terms/identifier -> 2017815837.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/407.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:15+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://omeka.org/s/vocabs/o#id -> 375.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://omeka.org/s/vocabs/o#id -> 371.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2017762724/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://purl.org/dc/terms/date -> 1937-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://omeka.org/s/vocabs/o#title -> George Peabody Library, formerly the Library of the Peabody Institute of the City of Baltimore, is part of the Johns Hopkins Sheridan Libraries. Baltimore, Maryland.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://purl.org/dc/terms/title -> Little Rock Public Library, Little Rock, Ark..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://purl.org/dc/terms/identifier -> 98508385.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/419.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:16+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://omeka.org/s/vocabs/o#title -> Public library in the southwestern section of Mississippi, in the piney woods.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:17+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/404.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://purl.org/dc/terms/rights -> No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://purl.org/dc/terms/title -> Public library in the southwestern section of Mississippi, in the piney woods.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:18+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/392.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://purl.org/dc/terms/date -> 1926-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:14+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:13+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/406 -> http://omeka.org/s/vocabs/o#id -> 406.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:13+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/387.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:17+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://omeka.org/s/vocabs/o#id -> 403.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://omeka.org/s/vocabs/o#title -> Carnegie Library, Cordele, Georgia.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://purl.org/dc/terms/identifier -> 87694100.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://omeka.org/s/vocabs/o#id -> 376.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://omeka.org/s/vocabs/o#id -> 373.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://purl.org/dc/terms/rights -> Undetermined.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://purl.org/dc/terms/rights -> No known restrictions on publication..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://purl.org/dc/terms/rights -> No known restrictions on publication..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://purl.org/dc/terms/title -> Libraries, Washington D.C..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/393.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://purl.org/dc/terms/rights -> No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:15+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/419.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://purl.org/dc/terms/date -> 1909-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/97511671/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/410.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/392.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/409.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://purl.org/dc/terms/date -> 1941-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/98508385/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/391 -> http://omeka.org/s/vocabs/o#id -> 391.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://purl.org/dc/terms/title -> [Cossitt Library, Memphis, Tenn.].
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/410.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://purl.org/dc/terms/rights -> No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/396.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://purl.org/dc/terms/title -> Carnegie Library, Cordele, Georgia.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://purl.org/dc/terms/rights -> No known restrictions on publication..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://purl.org/dc/terms/date -> 1936-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2016815290/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:20+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/418 -> http://omeka.org/s/vocabs/o#id -> 418.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/384 -> http://omeka.org/s/vocabs/o#id -> 384.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/390.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://purl.org/dc/terms/identifier -> 2017815837.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2017770391/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/404 -> http://omeka.org/s/vocabs/o#id -> 404.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/406.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/408.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://omeka.org/s/vocabs/o#id -> 368.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://purl.org/dc/terms/title -> [Cossitt Library, Memphis, Tenn.].
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://purl.org/dc/terms/title -> Newspaper reading room of public library. Omaha, Nebraska.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://purl.org/dc/terms/rights -> No known restrictions on publication..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://omeka.org/s/vocabs/o#title -> For greater knowledge on more subjects use your library more often.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://purl.org/dc/terms/date -> 2015-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://purl.org/dc/terms/title -> For greater knowledge on more subjects use your library more often.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/87694100/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2017762724/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://purl.org/dc/terms/date -> 1916-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:17+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://purl.org/dc/terms/title -> Public library building in the town of Antonito in Conejos County, Colorado, near the New Mexico border.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/384.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:18+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/396 -> http://omeka.org/s/vocabs/o#id -> 396.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:17+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://purl.org/dc/terms/rights -> No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/383 -> http://omeka.org/s/vocabs/o#id -> 383.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://purl.org/dc/terms/identifier -> 2017843202.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://purl.org/dc/terms/title -> Little Rock Public Library, Little Rock, Ark..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://omeka.org/s/vocabs/o#modified -> 2024-11-13T20:24:18+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/98508385/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://omeka.org/s/vocabs/o#title -> Library tent at the FSA (Farm Security Administration) mobile camp for migratory farm workers. Odell, Oregon. The girls working in the library receive credit in the Junior Campers League for work in the library.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/385.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://omeka.org/s/vocabs/o#title -> Little Rock Public Library, Little Rock, Ark..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://purl.org/dc/terms/identifier -> 91787443.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/395 -> http://omeka.org/s/vocabs/o#id -> 395.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://purl.org/dc/terms/rights -> No known restrictions on publication..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2016809661/.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/390 -> http://omeka.org/s/vocabs/o#id -> 390.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://omeka.org/s/vocabs/o#title -> Little Rock Public Library, Little Rock, Ark..
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://omeka.org/s/vocabs/o#owner -> http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://omeka.org/s/vocabs/o#id -> 411.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://purl.org/dc/terms/type -> Image.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/386 -> http://omeka.org/s/vocabs/o#id -> 386.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://omeka.org/s/vocabs/o#title -> Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/385.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://omeka.org/s/vocabs/o#is_public -> true.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://omeka.org/s/vocabs/o#primary_media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/382.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/419 -> http://omeka.org/s/vocabs/o#id -> 419.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://omeka.org/s/vocabs/o#media -> http://jajohnst.si676.si.umich.edu/omeka-s/api/media/389.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://purl.org/dc/terms/title -> Library tent at the FSA (Farm Security Administration) mobile camp for migratory farm workers. Odell, Oregon. The girls working in the library receive credit in the Junior Campers League for work in the library.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://purl.org/dc/terms/identifier -> 2016809661.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://omeka.org/s/vocabs/o#created -> 2024-11-13T20:24:15+00:00.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://omeka.org/s/vocabs/o#title -> Newspaper reading room of public library. Omaha, Nebraska.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/media/407 -> http://omeka.org/s/vocabs/o#id -> 407.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://purl.org/dc/terms/title -> George Peabody Library, formerly the Library of the Peabody Institute of the City of Baltimore, is part of the Johns Hopkins Sheridan Libraries. Baltimore, Maryland.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://purl.org/dc/terms/date -> 1941-01-01.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://omeka.org/s/vocabs/o#site -> http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://purl.org/dc/terms/isFormatOf -> {'map': 'https://www.loc.gov/search/?fa=original_format:map&fo=json'}.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://purl.org/dc/terms/date -> 1905-01-01.

# %% [markdown]
# ### Outputting, saving, and serializing
#
# Convert the graph to 'Turtle' format

# %%
ser = g.serialize(format='turtle')

print(ser)
# Out:
# @prefix ns1: <http://purl.org/dc/terms/> .
# @prefix ns2: <http://omeka.org/s/vocabs/o#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:13+00:00"^^xsd:dateTime ;
#     ns2:id 367 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/382> ;
#     ns2:modified "2024-11-13T20:24:13+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/382> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Carnegie Library, Cordele, Georgia" ;
#     ns1:date "1916-01-01"@en-us ;
#     ns1:identifier "91787443"@en-us,
#         "https://www.loc.gov/item/91787443/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions on publication."@en-us ;
#     ns1:title "Carnegie Library, Cordele, Georgia"@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:13+00:00"^^xsd:dateTime ;
#     ns2:id 368 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/383> ;
#     ns2:modified "2024-11-13T20:24:13+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/383> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Carnegie Library, Sheldon, Iowa" ;
#     ns1:date "1909-01-01"@en-us ;
#     ns1:identifier "97511671"@en-us,
#         "https://www.loc.gov/item/97511671/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "Undetermined"@en-us ;
#     ns1:title "Carnegie Library, Sheldon, Iowa"@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:13+00:00"^^xsd:dateTime ;
#     ns2:id 369 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/384> ;
#     ns2:modified "2024-11-13T20:24:13+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/384> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Curb service 10,000 current books - convenient, free, time saving : Chicago Public Library, Randolph St. corridor." ;
#     ns1:date "1936-01-01"@en-us ;
#     ns1:identifier "98508385"@en-us,
#         "https://www.loc.gov/item/98508385/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions on publication."@en-us ;
#     ns1:title "Curb service 10,000 current books - convenient, free, time saving : Chicago Public Library, Randolph St. corridor."@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:13+00:00"^^xsd:dateTime ;
#     ns2:id 370 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/385> ;
#     ns2:modified "2024-11-13T20:24:13+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/385> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "For greater knowledge on more subjects use your library more often" ;
#     ns1:date "1936-01-01"@en-us ;
#     ns1:identifier "98508155"@en-us,
#         "https://www.loc.gov/item/98508155/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions on publication."@en-us ;
#     ns1:title "For greater knowledge on more subjects use your library more often"@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:14+00:00"^^xsd:dateTime ;
#     ns2:id 371 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/386> ;
#     ns2:modified "2024-11-13T20:24:14+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/386> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "[Cossitt Library, Memphis, Tenn.]" ;
#     ns1:date "1906-01-01"@en-us ;
#     ns1:identifier "2016809661"@en-us,
#         "https://www.loc.gov/item/2016809661/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions on publication."@en-us ;
#     ns1:title "[Cossitt Library, Memphis, Tenn.]"@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:14+00:00"^^xsd:dateTime ;
#     ns2:id 372 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/387> ;
#     ns2:modified "2024-11-13T20:24:14+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/387> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Little Rock Public Library, Little Rock, Ark." ;
#     ns1:date "1905-01-01"@en-us ;
#     ns1:identifier "2016815290"@en-us,
#         "https://www.loc.gov/item/2016815290/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions on publication."@en-us ;
#     ns1:title "Little Rock Public Library, Little Rock, Ark."@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:14+00:00"^^xsd:dateTime ;
#     ns2:id 373 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/388> ;
#     ns2:modified "2024-11-13T20:24:14+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/388> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Newspaper reading room of public library. Omaha, Nebraska" ;
#     ns1:date "1938-01-01"@en-us ;
#     ns1:identifier "2017762724"@en-us,
#         "https://www.loc.gov/item/2017762724/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html"@en-us ;
#     ns1:title "Newspaper reading room of public library. Omaha, Nebraska"@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:15+00:00"^^xsd:dateTime ;
#     ns2:id 374 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/389> ;
#     ns2:modified "2024-11-13T20:24:15+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/389> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Public library in the southwestern section of Mississippi, in the piney woods" ;
#     ns1:date "1937-01-01"@en-us ;
#     ns1:identifier "2017770391"@en-us,
#         "https://www.loc.gov/item/2017770391/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html"@en-us ;
#     ns1:title "Public library in the southwestern section of Mississippi, in the piney woods"@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:15+00:00"^^xsd:dateTime ;
#     ns2:id 375 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/390> ;
#     ns2:modified "2024-11-13T20:24:15+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/390> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Library tent at the FSA (Farm Security Administration) mobile camp for migratory farm workers. Odell, Oregon. The girls working in the library receive credit in the Junior Campers League for work in the library" ;
#     ns1:date "1941-01-01"@en-us ;
#     ns1:identifier "2017815837"@en-us,
#         "https://www.loc.gov/item/2017815837/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html"@en-us ;
#     ns1:title "Library tent at the FSA (Farm Security Administration) mobile camp for migratory farm workers. Odell, Oregon. The girls working in the library receive credit in the Junior Campers League for work in the library"@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:15+00:00"^^xsd:dateTime ;
#     ns2:id 376 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/391> ;
#     ns2:modified "2024-11-13T20:24:15+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/391> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room" ;
#     ns1:date "1943-01-01"@en-us ;
#     ns1:identifier "2017843202"@en-us,
#         "https://www.loc.gov/item/2017843202/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html"@en-us ;
#     ns1:title "Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room"@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:16+00:00"^^xsd:dateTime ;
#     ns2:id 377 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/392> ;
#     ns2:modified "2024-11-13T20:24:16+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/392> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Libraries, Washington D.C." ;
#     ns1:date "1926-01-01"@en-us ;
#     ns1:identifier "87694100"@en-us,
#         "https://www.loc.gov/item/87694100/"@en-us ;
#     ns1:isFormatOf "{'map': 'https://www.loc.gov/search/?fa=original_format:map&fo=json'}"@en-us ;
#     ns1:rights "Undetermined"@en-us ;
#     ns1:title "Libraries, Washington D.C."@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:16+00:00"^^xsd:dateTime ;
#     ns2:id 378 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/393> ;
#     ns2:modified "2024-11-13T20:24:16+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/393> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Carnegie Library, Cordele, Georgia" ;
#     ns1:date "1916-01-01"@en-us ;
#     ns1:identifier "91787443"@en-us,
#         "https://www.loc.gov/item/91787443/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions on publication."@en-us ;
#     ns1:title "Carnegie Library, Cordele, Georgia"@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:16+00:00"^^xsd:dateTime ;
#     ns2:id 379 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/394> ;
#     ns2:modified "2024-11-13T20:24:16+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/394> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Carnegie Library, Sheldon, Iowa" ;
#     ns1:date "1909-01-01"@en-us ;
#     ns1:identifier "97511671"@en-us,
#         "https://www.loc.gov/item/97511671/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "Undetermined"@en-us ;
#     ns1:title "Carnegie Library, Sheldon, Iowa"@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:17+00:00"^^xsd:dateTime ;
#     ns2:id 380 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/395> ;
#     ns2:modified "2024-11-13T20:24:17+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/395> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Curb service 10,000 current books - convenient, free, time saving : Chicago Public Library, Randolph St. corridor." ;
#     ns1:date "1936-01-01"@en-us ;
#     ns1:identifier "98508385"@en-us,
#         "https://www.loc.gov/item/98508385/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions on publication."@en-us ;
#     ns1:title "Curb service 10,000 current books - convenient, free, time saving : Chicago Public Library, Randolph St. corridor."@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:17+00:00"^^xsd:dateTime ;
#     ns2:id 381 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/396> ;
#     ns2:modified "2024-11-13T20:24:17+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/396> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "For greater knowledge on more subjects use your library more often" ;
#     ns1:date "1936-01-01"@en-us ;
#     ns1:identifier "98508155"@en-us,
#         "https://www.loc.gov/item/98508155/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions on publication."@en-us ;
#     ns1:title "For greater knowledge on more subjects use your library more often"@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:17+00:00"^^xsd:dateTime ;
#     ns2:id 397 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/404> ;
#     ns2:modified "2024-11-13T20:24:17+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/404> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "[Cossitt Library, Memphis, Tenn.]" ;
#     ns1:date "1906-01-01"@en-us ;
#     ns1:identifier "2016809661"@en-us,
#         "https://www.loc.gov/item/2016809661/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions on publication."@en-us ;
#     ns1:title "[Cossitt Library, Memphis, Tenn.]"@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:17+00:00"^^xsd:dateTime ;
#     ns2:id 398 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/405> ;
#     ns2:modified "2024-11-13T20:24:17+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/405> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Little Rock Public Library, Little Rock, Ark." ;
#     ns1:date "1905-01-01"@en-us ;
#     ns1:identifier "2016815290"@en-us,
#         "https://www.loc.gov/item/2016815290/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions on publication."@en-us ;
#     ns1:title "Little Rock Public Library, Little Rock, Ark."@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:18+00:00"^^xsd:dateTime ;
#     ns2:id 399 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/406> ;
#     ns2:modified "2024-11-13T20:24:18+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/406> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Newspaper reading room of public library. Omaha, Nebraska" ;
#     ns1:date "1938-01-01"@en-us ;
#     ns1:identifier "2017762724"@en-us,
#         "https://www.loc.gov/item/2017762724/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html"@en-us ;
#     ns1:title "Newspaper reading room of public library. Omaha, Nebraska"@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:18+00:00"^^xsd:dateTime ;
#     ns2:id 400 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/407> ;
#     ns2:modified "2024-11-13T20:24:18+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/407> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Public library in the southwestern section of Mississippi, in the piney woods" ;
#     ns1:date "1937-01-01"@en-us ;
#     ns1:identifier "2017770391"@en-us,
#         "https://www.loc.gov/item/2017770391/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html"@en-us ;
#     ns1:title "Public library in the southwestern section of Mississippi, in the piney woods"@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:18+00:00"^^xsd:dateTime ;
#     ns2:id 401 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/408> ;
#     ns2:modified "2024-11-13T20:24:18+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/408> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Library tent at the FSA (Farm Security Administration) mobile camp for migratory farm workers. Odell, Oregon. The girls working in the library receive credit in the Junior Campers League for work in the library" ;
#     ns1:date "1941-01-01"@en-us ;
#     ns1:identifier "2017815837"@en-us,
#         "https://www.loc.gov/item/2017815837/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html"@en-us ;
#     ns1:title "Library tent at the FSA (Farm Security Administration) mobile camp for migratory farm workers. Odell, Oregon. The girls working in the library receive credit in the Junior Campers League for work in the library"@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:19+00:00"^^xsd:dateTime ;
#     ns2:id 402 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/409> ;
#     ns2:modified "2024-11-13T20:24:19+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/409> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room" ;
#     ns1:date "1943-01-01"@en-us ;
#     ns1:identifier "2017843202"@en-us,
#         "https://www.loc.gov/item/2017843202/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html"@en-us ;
#     ns1:title "Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room"@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:19+00:00"^^xsd:dateTime ;
#     ns2:id 403 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/410> ;
#     ns2:modified "2024-11-13T20:24:19+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/410> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Libraries, Washington D.C." ;
#     ns1:date "1926-01-01"@en-us ;
#     ns1:identifier "87694100"@en-us,
#         "https://www.loc.gov/item/87694100/"@en-us ;
#     ns1:isFormatOf "{'map': 'https://www.loc.gov/search/?fa=original_format:map&fo=json'}"@en-us ;
#     ns1:rights "Undetermined"@en-us ;
#     ns1:title "Libraries, Washington D.C."@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:19+00:00"^^xsd:dateTime ;
#     ns2:id 411 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/417> ;
#     ns2:modified "2024-11-13T20:24:19+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/417> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "George Peabody Library, formerly the Library of the Peabody Institute of the City of Baltimore, is part of the Johns Hopkins Sheridan Libraries. Baltimore, Maryland" ;
#     ns1:date "2012-01-01"@en-us ;
#     ns1:identifier "2013646466"@en-us,
#         "https://www.loc.gov/item/2013646466/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions on publication."@en-us ;
#     ns1:title "George Peabody Library, formerly the Library of the Peabody Institute of the City of Baltimore, is part of the Johns Hopkins Sheridan Libraries. Baltimore, Maryland"@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:20+00:00"^^xsd:dateTime ;
#     ns2:id 412 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/418> ;
#     ns2:modified "2024-11-13T20:24:20+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/418> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Handley Library, Winchester, Virginia" ;
#     ns1:date "2011-01-01"@en-us ;
#     ns1:identifier "2012630178"@en-us,
#         "https://www.loc.gov/item/2012630178/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions on publication."@en-us ;
#     ns1:title "Handley Library, Winchester, Virginia"@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413> a ns2:Item ;
#     ns2:created "2024-11-13T20:24:20+00:00"^^xsd:dateTime ;
#     ns2:id 413 ;
#     ns2:is_public true ;
#     ns2:media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/419> ;
#     ns2:modified "2024-11-13T20:24:20+00:00"^^xsd:dateTime ;
#     ns2:owner <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ;
#     ns2:primary_media <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/419> ;
#     ns2:site <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ;
#     ns2:title "Public library building in the town of Antonito in Conejos County, Colorado, near the New Mexico border" ;
#     ns1:date "2015-01-01"@en-us ;
#     ns1:identifier "2017686535"@en-us,
#         "https://www.loc.gov/item/2017686535/"@en-us ;
#     ns1:isFormatOf "{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}"@en-us ;
#     ns1:rights "No known restrictions on publication."@en-us ;
#     ns1:title "Public library building in the town of Antonito in Conejos County, Colorado, near the New Mexico border"@en-us ;
#     ns1:type "Image"@en-us .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/382> ns2:id 382 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/383> ns2:id 383 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/384> ns2:id 384 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/385> ns2:id 385 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/386> ns2:id 386 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/387> ns2:id 387 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/388> ns2:id 388 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/389> ns2:id 389 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/390> ns2:id 390 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/391> ns2:id 391 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/392> ns2:id 392 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/393> ns2:id 393 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/394> ns2:id 394 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/395> ns2:id 395 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/396> ns2:id 396 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/404> ns2:id 404 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/405> ns2:id 405 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/406> ns2:id 406 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/407> ns2:id 407 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/408> ns2:id 408 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/409> ns2:id 409 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/410> ns2:id 410 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/417> ns2:id 417 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/418> ns2:id 418 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/media/419> ns2:id 419 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/sites/1> ns2:id 1 .
#
# <http://jajohnst.si676.si.umich.edu/omeka-s/api/users/1> ns2:id 1 .

# %% [markdown]
# Save it to a file

# %%
with open('item-set-graph-1.ttl', 'w') as f:
    f.write(ser)

# %% [markdown]
# ## Parsing, Modifying, and Adding to the Graph
#
# Now try to remove the Omeka data in order to get a closer look
# at the collection specific data.

# %%
# remove the omeka specific data
for triple in g:
    if 'http://omeka.org/s/vocabs/o#' in triple[1]:
        g.remove(triple)

# %%
for s, p, o in g:
    print(f'{s} -> {p} -> {o}')
# Out:
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://purl.org/dc/terms/date -> 1906-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://purl.org/dc/terms/date -> 2012-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://purl.org/dc/terms/rights -> No known restrictions on publication.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://purl.org/dc/terms/identifier -> 2017770391
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://purl.org/dc/terms/date -> 1936-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://purl.org/dc/terms/identifier -> 2013646466
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://purl.org/dc/terms/rights -> Undetermined
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://purl.org/dc/terms/identifier -> 2012630178
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2012630178/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://purl.org/dc/terms/title -> Carnegie Library, Cordele, Georgia
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://purl.org/dc/terms/identifier -> 87694100
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://purl.org/dc/terms/identifier -> 91787443
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://purl.org/dc/terms/identifier -> 2017762724
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://purl.org/dc/terms/isFormatOf -> {'map': 'https://www.loc.gov/search/?fa=original_format:map&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://purl.org/dc/terms/identifier -> 97511671
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://purl.org/dc/terms/date -> 1937-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://purl.org/dc/terms/title -> Newspaper reading room of public library. Omaha, Nebraska
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://purl.org/dc/terms/identifier -> 98508155
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2017843202/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://purl.org/dc/terms/date -> 1938-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://purl.org/dc/terms/identifier -> 2017843202
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2017815837/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://purl.org/dc/terms/rights -> No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://purl.org/dc/terms/date -> 1938-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://purl.org/dc/terms/date -> 1905-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://purl.org/dc/terms/date -> 2011-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://purl.org/dc/terms/title -> Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://purl.org/dc/terms/rights -> Undetermined
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://purl.org/dc/terms/rights -> No known restrictions on publication.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://purl.org/dc/terms/rights -> No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2016809661/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://purl.org/dc/terms/rights -> No known restrictions on publication.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://purl.org/dc/terms/rights -> No known restrictions on publication.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://purl.org/dc/terms/title -> Carnegie Library, Sheldon, Iowa
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://purl.org/dc/terms/date -> 1909-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/98508155/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://purl.org/dc/terms/title -> Carnegie Library, Sheldon, Iowa
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/91787443/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://purl.org/dc/terms/title -> Curb service 10,000 current books - convenient, free, time saving : Chicago Public Library, Randolph St. corridor.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/97511671/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/91787443/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://purl.org/dc/terms/identifier -> 2017815837
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://purl.org/dc/terms/rights -> Undetermined
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://purl.org/dc/terms/date -> 1916-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2017762724/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2016815290/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://purl.org/dc/terms/date -> 1937-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://purl.org/dc/terms/title -> Little Rock Public Library, Little Rock, Ark.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://purl.org/dc/terms/identifier -> 98508385
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://purl.org/dc/terms/title -> Libraries, Washington D.C.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://purl.org/dc/terms/rights -> No known restrictions on publication.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/87694100/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://purl.org/dc/terms/rights -> No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://purl.org/dc/terms/title -> Public library in the southwestern section of Mississippi, in the piney woods
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://purl.org/dc/terms/date -> 1926-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://purl.org/dc/terms/identifier -> 87694100
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://purl.org/dc/terms/rights -> Undetermined
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://purl.org/dc/terms/rights -> No known restrictions on publication.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://purl.org/dc/terms/rights -> No known restrictions on publication.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://purl.org/dc/terms/title -> Libraries, Washington D.C.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://purl.org/dc/terms/rights -> No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://purl.org/dc/terms/date -> 1936-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://purl.org/dc/terms/title -> Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://purl.org/dc/terms/date -> 1909-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2017815837/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://purl.org/dc/terms/date -> 1943-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://purl.org/dc/terms/date -> 1936-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/97511671/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://purl.org/dc/terms/title -> Library tent at the FSA (Farm Security Administration) mobile camp for migratory farm workers. Odell, Oregon. The girls working in the library receive credit in the Junior Campers League for work in the library
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://purl.org/dc/terms/date -> 1926-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://purl.org/dc/terms/identifier -> 2016815290
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://purl.org/dc/terms/date -> 1941-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://purl.org/dc/terms/identifier -> 2016809661
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/98508385/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://purl.org/dc/terms/identifier -> 2016815290
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://purl.org/dc/terms/rights -> No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://purl.org/dc/terms/title -> [Cossitt Library, Memphis, Tenn.]
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/98508155/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2017770391/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://purl.org/dc/terms/rights -> No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://purl.org/dc/terms/title -> Carnegie Library, Cordele, Georgia
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://purl.org/dc/terms/identifier -> 97511671
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://purl.org/dc/terms/rights -> No known restrictions on publication.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://purl.org/dc/terms/date -> 1936-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2016815290/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://purl.org/dc/terms/identifier -> 2017815837
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://purl.org/dc/terms/identifier -> 2017762724
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2017770391/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://purl.org/dc/terms/title -> Public library in the southwestern section of Mississippi, in the piney woods
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://purl.org/dc/terms/title -> [Cossitt Library, Memphis, Tenn.]
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://purl.org/dc/terms/title -> Newspaper reading room of public library. Omaha, Nebraska
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/380 -> http://purl.org/dc/terms/rights -> No known restrictions on publication.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/368 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://purl.org/dc/terms/rights -> No known restrictions on publication.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/399 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://purl.org/dc/terms/rights -> No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/379 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://purl.org/dc/terms/title -> Handley Library, Winchester, Virginia
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://purl.org/dc/terms/date -> 2015-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://purl.org/dc/terms/title -> For greater knowledge on more subjects use your library more often
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/403 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/87694100/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/374 -> http://purl.org/dc/terms/identifier -> 2017770391
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2017762724/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://purl.org/dc/terms/date -> 1916-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://purl.org/dc/terms/title -> Public library building in the town of Antonito in Conejos County, Colorado, near the New Mexico border
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2017843202/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/412 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://purl.org/dc/terms/title -> Curb service 10,000 current books - convenient, free, time saving : Chicago Public Library, Randolph St. corridor.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/400 -> http://purl.org/dc/terms/rights -> No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://purl.org/dc/terms/identifier -> 98508155
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/402 -> http://purl.org/dc/terms/identifier -> 2017843202
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://omeka.org/s/vocabs/o#Item
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/372 -> http://purl.org/dc/terms/title -> Little Rock Public Library, Little Rock, Ark.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2013646466/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2017686535/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/98508385/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/378 -> http://purl.org/dc/terms/identifier -> 91787443
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/370 -> http://purl.org/dc/terms/rights -> No known restrictions on publication.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://purl.org/dc/terms/date -> 1906-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://purl.org/dc/terms/identifier -> https://www.loc.gov/item/2016809661/
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/369 -> http://purl.org/dc/terms/identifier -> 98508385
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/376 -> http://purl.org/dc/terms/date -> 1943-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/397 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/413 -> http://purl.org/dc/terms/identifier -> 2017686535
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/373 -> http://purl.org/dc/terms/isFormatOf -> {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://purl.org/dc/terms/rights -> No known restrictions on publication.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/375 -> http://purl.org/dc/terms/title -> Library tent at the FSA (Farm Security Administration) mobile camp for migratory farm workers. Odell, Oregon. The girls working in the library receive credit in the Junior Campers League for work in the library
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://purl.org/dc/terms/identifier -> 2016809661
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/381 -> http://purl.org/dc/terms/title -> For greater knowledge on more subjects use your library more often
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/401 -> http://purl.org/dc/terms/date -> 1941-01-01
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/411 -> http://purl.org/dc/terms/title -> George Peabody Library, formerly the Library of the Peabody Institute of the City of Baltimore, is part of the Johns Hopkins Sheridan Libraries. Baltimore, Maryland
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/367 -> http://purl.org/dc/terms/type -> Image
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/371 -> http://purl.org/dc/terms/rights -> No known restrictions on publication.
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/377 -> http://purl.org/dc/terms/isFormatOf -> {'map': 'https://www.loc.gov/search/?fa=original_format:map&fo=json'}
# http://jajohnst.si676.si.umich.edu/omeka-s/api/items/398 -> http://purl.org/dc/terms/date -> 1905-01-01

# %% [markdown]
# ### Adding the "newData"

# %%
# add the "newData" by looping (iterating) through the data
# and adding to the appropriate elements

# Note: this will only work if the Keys are in the extant data so the data must be uploaded and added first

for nameKey in newData: 
    for s, p, o, in g.triples((None, FOAF.name, Literal(nameKey))):
        deathDate = newData[o.value]['https://schema.org/deathDate']
        deathPlace = newData[o.value]['https://schema.org/deathPlace']
        g.add((s, URIRef('https://schema.org/deatDate'), Literal(deathDate)))
        g.add((s, URIRef('https://schema.org/deathPlace'), URIRef(deathPlace)))

# %% [markdown]
# To demonstrate how the graph changed, serialize the new graph

# %%
ser2 = g.serialize(format='turtle')

with open('item-set-graph-2.ttl', 'w') as f:
    f.write(ser2)
